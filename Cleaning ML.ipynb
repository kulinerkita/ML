# %% [markdown]
# # Import Library

# %%
import pandas as pd
from os import getcwd
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
import re
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cwd = getcwd() + "/drive/Shareddrives/CAPSTONE_ML/all_data/"
print(cwd)
# Out:
# /content/drive/Shareddrives/CAPSTONE_ML/all_data/

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## 1. Gathering

# %%
dir = cwd
df_wedanguwuh = pd.read_excel(dir+'wedang_uwuh_solo.xlsx')
df_timlo = pd.read_excel(dir+'timlo_solo.xlsx')
df_tahok = pd.read_excel(dir+'tahok_solo.xlsx')
df_soto = pd.read_excel(dir+'soto_solo.xlsx')
df_serabi = pd.read_excel(dir+'serabi_solo.xlsx')
df_selat = pd.read_excel(dir+'selat_solo.xlsx')
df_segoliwet = pd.read_excel(dir+'sego_liwet_solo.xlsx')
df_satekere = pd.read_excel(dir+'sate_kere_solo.xlsx')
df_satebuntel = pd.read_excel(dir+'sate_buntel_solo.xlsx')
df_lenjongan = pd.read_excel(dir+'lenjongan_solo.xlsx')
df_gudeg = pd.read_excel(dir+'gudeg_solo.xlsx')
df_gendarpecel = pd.read_excel(dir+'gendar_pecel_solo.xlsx')
df_asle = pd.read_excel(dir+'es_wedang_asle.xlsx')
df_eskapal = pd.read_excel(dir+'es_kapal_solo.xlsx')
df_esgempol = pd.read_excel(dir+'es_gempol_pleret_solo.xlsx')
df_dawettelasih = pd.read_excel(dir+'es_dawet_telasih_solo.xlsx')
df_brambangasem = pd.read_excel(dir+'brambang_asem_solo.xlsx')

# %%
df_wedanguwuh.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Uwuh+...
# 1  https://www.google.com/maps/place/Rajanya+JAHE...
# 2  https://www.google.com/maps/place/Wedang+uwuh+...
# 3  https://www.google.com/maps/place/Wedang+uwuh+...
# 4  https://www.google.com/maps/place/wedang+uwuh+...
#
#                                       Text Rating Reviews     Kategori  \
# 0              Wedang Uwuh Solo - Pak Aden    4,6     (5)  Wedang Uwuh
# 1  Rajanya JAHE REMPAH wedhang uwuh Sumber    4,6    (32)  Wedang Uwuh
# 2                Wedang uwuh jelantik solo    5,0     (1)  Wedang Uwuh
# 3                     Wedang uwuh mbok tuo    4,9    (14)  Wedang Uwuh
# 4                          wedang uwuh sya    4,7     (3)  Wedang Uwuh
#
#                                              Address  Website    Phone_Number  \
# 0  \nMutihan rt 04 rw 1, Surakarta, Sondakan, Ke...      NaN  0823-2400-6000
# 1  \nJl. Letjen Suprapto No.76c, Sumber, Kec. Ba...      NaN  0856-4172-7445
# 2  \nJl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kl...      NaN  0812-2907-0267
# 3  \nJl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec...      NaN  0815-7861-4885
# 4  \nJl. Reksoniten No.20, Gajahan, Kec. Ps. Kli...      NaN  0896-0814-9211
#
#    Photo                                      Opening_Hours Range_Harga  \
# 0    NaN  Senin\n08.00–20.00\nSelasa\n08.00–20.00\nRabu\...         NaN
# 1    NaN                                                NaN         NaN
# 2    NaN  Senin\nBuka 24 jam\nSelasa\nBuka 24 jam\nRabu\...         NaN
# 3    NaN  Senin\n07.00–19.00\nSelasa\n07.00–19.00\nRabu\...         NaN
# 4    NaN                                                NaN         NaN
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.566731  110.716919
# 1            NaN -7.566731  110.716919
# 2            NaN -7.576765  110.768229
# 3            NaN -7.547894  110.730811
# 4            NaN -7.547894  110.730811

# %%
df_timlo.head()
# Out:
#                                             Page_URL                  Text  \
# 0  https://www.google.com/maps/place/RM+Timlo+Sol...         RM Timlo Solo
# 1  https://www.google.com/maps/place/Timlo+Sastro...        Timlo Sastro 2
# 2  https://www.google.com/maps/place/Timlo+Khas+S...       Timlo Khas Solo
# 3  https://www.google.com/maps/place/Timlo+Sastro...        Timlo Sastro 1
# 4  https://www.google.com/maps/place/Timlo+Asli+S...  Timlo Asli Solo Baru
#
#   Rating  Reviews Kategori                                            Address  \
# 0    4,3  (3.374)    Timlo  \nJl. Jend. Urip Sumoharjo No.94, Purwodining...
# 1    4,3  (2.334)    Timlo  \nJl. Dr. Wahidin No.30, Purwosari, Kec. Lawe...
# 2    4,3     (53)    Timlo  \nSolo Grand Mall, Jl. Slamet Riyadi No.271, ...
# 3    4,5  (2.886)    Timlo  \nJl. Abdul Muis No.32A, Kepatihan Kulon, Kec...
# 4    4,6     (20)    Timlo  \nJl. Cendrawasih Jl. Raya Solo Baru No.C43, ...
#
#    Website    Phone_Number  Photo  \
# 0      NaN  0851-0083-5676    NaN
# 1      NaN   (0271) 728981    NaN
# 2      NaN  0870-3613-1441    NaN
# 3      NaN   (0271) 654820    NaN
# 4      NaN             NaN    NaN
#
#                                        Opening_Hours  Range_Harga  \
# 0  Senin\n08.00–20.00\nSelasa\n08.00–20.00\nRabu\...  Rp 25–50 rb
# 1  Senin\n07.00–21.00\nSelasa\n07.00–21.00\nRabu\...  Rp 25–50 rb
# 2  Senin\n09.00–21.00\nSelasa\n09.00–21.00\nRabu\...  Rp 1–25.000
# 3  Senin\n06.00–15.00\nSelasa\n06.00–15.00\nRabu\...  Rp 25–50 rb
# 4  Senin\n07.00–19.00\nSelasa\n07.00–19.00\nRabu\...          NaN
#
#                                       Deskripsi_Toko  Latitude   Longitude
# 0  Tempat makan sederhana yang menyajikan makanan... -7.564512  110.690428
# 1                                                NaN -7.564512  110.690428
# 2                                                NaN -7.564512  110.690428
# 3                                                NaN -7.564512  110.690428
# 4                                                NaN -7.564512  110.690428

# %%
df_soto.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Soto+Gading+...
# 1  https://www.google.com/maps/place/Soto+Triwind...
# 2  https://www.google.com/maps/place/Soto+Seger+H...
# 3  https://www.google.com/maps/place/Soto+Ayam+La...
# 4  https://www.google.com/maps/place/Soto+Ayam+Kh...
#
#                                    Text Rating  Reviews Kategori  \
# 0                         Soto Gading 1    4,4  (9.171)     Soto
# 1                         Soto Triwindu    4,5  (4.314)     Soto
# 2      Soto Seger Hj.Fatimah Restaurant    4,5  (9.855)     Soto
# 3  Soto Ayam Lamongan Cak Rin, Ngoresan    4,6    (253)     Soto
# 4    Soto Ayam Khas Semarang Pak Lasidi    4,5    (270)     Soto
#
#                                              Address  Website    Phone_Number  \
# 0  Jl. Brigjen Sudiarto No.75, Joyosuran, Kec. P...      NaN  0812-2714-5219
# 1  \nJl. Teuku Umar, Keprabon, Kec. Banjarsari, ...      NaN   (0271) 646006
# 2  \nJl. Bhayangkara No.72a, Tipes, Kec. Serenga...      NaN             NaN
# 3  \nCVW5+6Q7, Jebres, Kec. Jebres, Kota Surakar...      NaN             NaN
# 4  \nCRJQ+Q58, Jl. Ir. Juanda, Purwodiningratan,...      NaN  0857-2802-2888
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Senin\n06.00–16.00\nSelasa\n06.00–16.00\nRabu\...  Rp 1–25.000
# 1    NaN  Senin\n05.30–15.30\nSelasa\n05.30–15.30\nRabu\...  Rp 25–50 rb
# 2    NaN  Senin\n06.00–19.00\nSelasa\n06.00–19.00\nRabu\...  Rp 1–25.000
# 3    NaN  Senin\n06.00–15.30\nSelasa\n06.00–15.30\nRabu\...  Rp 1–25.000
# 4    NaN  Senin\n05.00–15.00\nSelasa\n05.00–15.00\nRabu\...  Rp 1–25.000
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.586845  110.680487
# 1            NaN -7.586845  110.680487
# 2            NaN -7.586845  110.680487
# 3            NaN -7.586845  110.680487
# 4            NaN -7.586845  110.680487

# %%
df_serabi.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Serabi+Khas+...
# 1  https://www.google.com/maps/place/Serabi+Notos...
# 2  https://www.google.com/maps/place/Serabi+Solo+...
# 3  https://www.google.com/maps/place/Srabi+Notosu...
# 4  https://www.google.com/maps/place/Serabi+Kemba...
#
#                              Text Rating  Reviews Kategori  \
# 0  Serabi Khas Notosuman H. Oemar    4,6    (856)   Serabi
# 1      Serabi Notosuman Ny. Lidia    4,6  (1.879)   Serabi
# 2    Serabi Solo Mas Fahri Sumber    4,5     (81)   Serabi
# 3   Srabi Notosuman Ny. Handayani    4,6    (597)   Serabi
# 4                   Serabi Kembar    4,5    (112)   Serabi
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Gatot Subroto No.215, Kratonan, Kec. Se...      NaN   (0271) 644745
# 1  \nJl. Moh. Yamin No.28, Jayengan, Kec. Sereng...      NaN   (0271) 651852
# 2  \nJl. Letjen Suprapto, Sumber, Kec. Banjarsar...      NaN  0896-6911-6814
# 3  \nJl. Moh. Yamin No.51, Kratonan, Kec. Sereng...      NaN   (0271) 655906
# 4  \nJalan Dawung Tengah No.31B, Serengan, Kec. ...      NaN   0812-2641-781
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Senin\n07.00–18.00\nSelasa\n07.00–18.00\nRabu\...  Rp 25–50 rb
# 1    NaN  Senin\n05.00–17.00\nSelasa\n05.00–17.00\nRabu\...  Rp 25–50 rb
# 2    NaN  Senin\n06.00–17.00\nSelasa\n06.00–17.00\nRabu\...  Rp 1–25.000
# 3    NaN  Senin\n04.30–17.00\nSelasa\n04.30–17.00\nRabu\...  Rp 25–50 rb
# 4    NaN  Senin\n07.00–00.00\nSelasa\n07.00–00.00\nRabu\...  Rp 1–25.000
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.561478  110.769035
# 1             NaN -7.561478  110.769035
# 2             NaN -7.547896  110.732103
# 3             NaN -7.547896  110.732103
# 4             NaN -7.586057  110.744275

# %%
df_selat.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Selat+Solo+T...
# 1  https://www.google.com/maps/place/Selat+Solo+T...
# 2  https://www.google.com/maps/place/Selat+Vien's...
# 3  https://www.google.com/maps/place/Selat+Pak+To...
# 4  https://www.google.com/maps/place/Warung+Selat...
#
#                                     Text Rating   Reviews Kategori  \
# 0    Selat Solo Tenda Biru - Dr. Wahidin    4,6   (7.090)    Selat
# 1  Selat Solo Tenda Biru - KH. Samanhudi    4,6     (771)    Selat
# 2                     Selat Vien's Pusat    4,5  (10.980)    Selat
# 3                           Selat Pak To    4,3   (1.454)    Selat
# 4        Warung Selat & Catering Anugrah    4,2      (87)    Selat
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Dr. Wahidin No.26, Purwosari, Kec. Lawe...      NaN  0821-3665-9775
# 1  \nJl. K.H Samanhudi No.1, Purwosari, Kec. Law...      NaN  0821-3665-9775
# 2  \nJl. Hasanudin No.99 D/E, Punggawan, Kec. Ba...      NaN   0811-2955-878
# 3  \n9QRM+4H3, Jl. WR. Supratman, Dusun II, Kadi...      NaN             NaN
# 4  \nGatak, Siswodipuran, Kec. Boyolali, Kabupat...      NaN  0857-0000-7890
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Senin\n08.00–21.00\nSelasa\n08.00–21.00\nRabu\...  Rp 25–50 rb
# 1    NaN  Senin\n09.00–18.00\nSelasa\n09.00–18.00\nRabu\...  Rp 1–25.000
# 2    NaN  Senin\n07.30–17.00\nSelasa\n07.30–17.00\nRabu\...  Rp 1–25.000
# 3    NaN  Senin\n08.00–23.55\nSelasa\n08.00–23.55\nRabu\...  Rp 1–25.000
# 4    NaN  Senin\n08.30–16.00\nSelasa\n08.30–16.00\nRabu\...            $
#
#                                       Deskripsi_Toko  Latitude   Longitude
# 0  Depot bernuansa santai dan simpel menyajikan a... -7.568656  110.516830
# 1                                                NaN -7.568656  110.516830
# 2                                                NaN -7.568656  110.516830
# 3                                                NaN -7.568656  110.516830
# 4                                                NaN -7.536113  110.318702

# %%
df_segoliwet.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Nasi+Liwet+Y...
# 1  https://www.google.com/maps/place/Nasi+Liwet+B...
# 2  https://www.google.com/maps/place/Nasi+Liwet+B...
# 3  https://www.google.com/maps/place/Nasi+Liwet+M...
# 4  https://www.google.com/maps/place/Nasi+Liwet+%...
#
#                              Text Rating  Reviews    Kategori  \
# 0    Nasi Liwet Yu Sani Gemblegan    4,5  (2.143)  Sego Liwet
# 1    Nasi Liwet Yu Sani Gemblegan    4,5  (2.143)  Sego Liwet
# 2  Nasi Liwet Bu Sarmi, Lojiwetan    4,4    (895)  Sego Liwet
# 3   Nasi Liwet Mbok MAMI Mbak Kus    4,5  (1.133)  Sego Liwet
# 4   Nasi Liwet Mbok MAMI Mbak Kus    4,5  (1.133)  Sego Liwet
#
#                                              Address  Website    Phone_Number  \
# 0  CR9C+3GQ, Jl. Veteran, Gajahan, Kec. Ps. Kliw...      NaN  0815-7848-5657
# 1  \nCR9C+3GQ, Jl. Veteran, Gajahan, Kec. Ps. Kl...      NaN  0815-7848-5657
# 2  \nJl. Kapten Mulyadi, Kedung Lumbu, Kec. Ps. ...      NaN             NaN
# 3  \nJl. Dr. Rajiman No.580, Sondakan, Kec. Lawe...      NaN  0857-4192-9659
# 4  \nJl. Dr. Rajiman No.580, Sondakan, Kec. Lawe...      NaN  0857-4192-9659
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Minggu\n17.00–23.00\nSenin\n17.00–23.00\nSelas...  Rp 1–25.000
# 1    NaN  Minggu\n16.00–00.00\nSenin\n16.00–01.00\nSelas...  Rp 1–25.000
# 2    NaN  Minggu\n18.00–00.00\nSenin\n18.00–00.00\nSelas...  Rp 1–25.000
# 3    NaN  Minggu\n17.30–02.00\nSenin\n17.30–02.00\nSelas...  Rp 1–25.000
# 4    NaN  Minggu\n18.00–23.00\nSenin\n18.00–23.00\nSelas...  Rp 1–25.000
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.582277  110.785317
# 1             NaN -7.582277  110.785317
# 2             NaN -7.582277  110.785317
# 3             NaN -7.568446  110.756125
# 4             NaN -7.580959  110.784967

# %%
df_satekere.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Sate+Kere+Yu...
# 1  https://www.google.com/maps/place/SATE+KERE+%2...
# 2  https://www.google.com/maps/place/Sate+Kere+Yu...
# 3  https://www.google.com/maps/place/Sate+Kere+Ba...
# 4  https://www.google.com/maps/place/SATE+KERE+Mb...
#
#                              Text Rating  Reviews   Kategori  \
# 0               Sate Kere Yu Tari    4,5     (36)  Sate Kere
# 1  SATE KERE "MAK NARTI " Widuran    4,6    (245)  Sate Kere
# 2               Sate Kere Yu Rebi    4,3  (1.191)  Sate Kere
# 3               Sate Kere Barokah    4,9     (26)  Sate Kere
# 4              SATE KERE Mbak Yun    5,0      (2)  Sate Kere
#
#                                              Address Website    Phone_Number  \
# 0  \nParkiran Sami Luwes, Jl. Honggowongso No.28...     NaN  0895-2626-2524
# 1  \nJl. Sutan Syahrir No.97, Kepatihan Kulon, K...     NaN  0857-2811-1923
# 2  \nCRJ6+4GG, Jl. Kebangkitan Nasional, Sriweda...     NaN  0857-7554-8206
# 3  \nFR4G+763, Kadipiro, Kec. Banjarsari, Kota S...     NaN             NaN
# 4  \nJl. Kahuripan No.50-38, Sumber, Kec. Banjar...     NaN  0857-2863-6811
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Minggu\n17.00–21.00\nSenin\n17.00–21.00\nSelas...  Rp 1–25.000
# 1    NaN  Minggu\n20.00–01.00\nSenin\n20.00–01.00\nSelas...  Rp 1–50.000
# 2    NaN  Minggu\n11.00–20.00\nSenin\n11.00–20.00\nSelas...  Rp 25–50 rb
# 3    NaN  Minggu\n17.00–21.00\nSenin\n17.00–21.00\nSelas...  Rp 1–25.000
# 4    NaN  Minggu\n16.00–22.00\nSenin\n16.15–22.00\nSelas...          NaN
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.569358  110.781006
# 1             NaN -7.569358  110.781006
# 2             NaN -7.569358  110.781006
# 3             NaN -7.544362  110.789494
# 4             NaN -7.546621  110.763859

# %%
df_satebuntel.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Sate+Kambing...
# 1  https://www.google.com/maps/place/Sate+Buntel+...
# 2  https://www.google.com/maps/place/Sate+Kambing...
# 3  https://www.google.com/maps/place/Sate+Kambing...
# 4  https://www.google.com/maps/place/Warung+Makan...
#
#                                            Text Rating   Reviews     Kategori  \
# 0              Sate Kambing-Buntel Pak H. Kasdi    4,5   (5.313)  Sate Buntel
# 1                            Sate Buntel Badran    4,7     (411)  Sate Buntel
# 2  Sate Kambing & Tengkleng Rica Rica Pak Manto    4,4  (15.636)  Sate Buntel
# 3                Sate Kambing Sumber Pak Dahlan    4,4   (2.773)  Sate Buntel
# 4                    Warung Makan Sate Mbak Tin    4,3     (487)  Sate Buntel
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Walter Monginsidi No.107, Kestalan, Kec...      NaN  0815-4830-0095
# 1  \nJl. Kenanga No.59, Badran, Purwosari, Kec. ...      NaN  0822-8958-7777
# 2  \nJl. Honggowongso No.36, Sriwedari, Kec. Law...      NaN  0812-2922-0448
# 3  \nJl. Letjen Suprapto No.69, Sumber, Kec. Ban...      NaN  0878-3655-5269
# 4  \nJl. Gatot Subroto No.285, Kratonan, Kec. Se...      NaN  0852-8070-2797
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Minggu\n07.00–21.00\nSenin\n07.00–21.00\nSelas...  Rp 25–50 rb
# 1    NaN  Minggu\n09.00–21.00\nSenin\n09.00–21.00\nSelas...  Rp 25–50 rb
# 2    NaN  Minggu\n07.30–20.00\nSenin\n07.30–20.00\nSelas...  Rp 50–75 rb
# 3    NaN  Minggu\n11.00–21.00\nSenin\n11.00–21.00\nSelas...  Rp 50–75 rb
# 4    NaN  Minggu\n08.00–22.00\nSenin\n08.00–22.00\nSelas...  Rp 25–50 rb
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.557588  110.534292
# 1            NaN -7.557588  110.534292
# 2            NaN -7.557588  110.534292
# 3            NaN -7.557588  110.534292
# 4            NaN -7.557588  110.534292

# %%
df_lenjongan.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Lenjongan/@-...
# 1  https://www.google.com/maps/place/Lenjongan+Yu...
#
#                         Text Rating Reviews   Kategori  \
# 0                  Lenjongan    4,0     (1)  Lenjongan
# 1  Lenjongan Yu Sum Ps.Gedhe    4,4    (51)  Lenjongan
#
#                                              Address  Website   Phone_Number  \
# 0  \nCRJ8+8QH, Sriwedari, Kec. Laweyan, Kota Sur...      NaN            NaN
# 1  \nJl. Jend. Urip Sumoharjo, Sudiroprajan, Kec...      NaN  (0271) 000000
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN                                                NaN          NaN
# 1    NaN  Minggu\n07.00–17.00\nSenin\n07.00–17.00\nSelas...  Rp 1–25.000
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.569179  110.807963
# 1             NaN -7.568962  110.822755

# %%
df_gudeg.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Gudeg+Solo+M...
# 1  https://www.google.com/maps/place/Gudeg+Mbak+Y...
# 2  https://www.google.com/maps/place/GUDEG+AYU+So...
# 3  https://www.google.com/maps/place/Gudeg+Solo+J...
# 4  https://www.google.com/maps/place/Gudeg+Ayu+So...
#
#                           Text Rating  Reviews Kategori  \
# 0    Gudeg Solo Mbak Sulandari    4,7    (589)    Gudeg
# 1               Gudeg Mbak Yus    4,4  (1.136)    Gudeg
# 2               Gudeg Mbak Yus    4,4  (1.136)    Gudeg
# 3           Gudeg Solo Javenir    4,4    (422)    Gudeg
# 4  Gudeg Ayu Solo (Kota Barat)    4,5    (388)    Gudeg
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Hasanudin No.109 C, Jawa Tengah, Kec. B...      NaN  0821-3486-8666
# 1  \nJl. RA Kartini No.12, Timuran, Kec. Banjars...      NaN  0812-8020-5859
# 2  \nJl. RA Kartini No.12, Timuran, Kec. Banjars...      NaN  0812-8020-5859
# 3  \nKomplek Javenir, Jl. Adi Sucipto No.48, Blu...      NaN  (0271) 7461795
# 4  \nJl. Doktor Moewardi No.33, Purwosari, Kec. ...      NaN   (0271) 740957
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Minggu\n08.00–16.00\nSenin\nTutup\nSelasa\n08....  Rp 25–50 rb
# 1    NaN                                                NaN  Rp 25–50 rb
# 2    NaN  Minggu\n06.45–21.00\nSenin\n06.45–21.00\nSelas...  Rp 25–50 rb
# 3    NaN  Minggu\n09.00–23.00\nSenin\n09.00–23.00\nSelas...  Rp 25–50 rb
# 4    NaN  Minggu\n06.00–19.00\nSenin\n06.00–19.00\nSelas...  Rp 25–50 rb
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.557978  110.673642
# 1            NaN -7.557978  110.673642
# 2            NaN -7.557978  110.673642
# 3            NaN -7.557978  110.673642
# 4            NaN -7.557978  110.673642

# %%
df_gendarpecel.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Gendar+Pecel...
# 1  https://www.google.com/maps/place/Gendar+pecel...
# 2  https://www.google.com/maps/place/Gendar+Pecel...
# 3  https://www.google.com/maps/place/Gendar+Pecel...
# 4  https://www.google.com/maps/place/Warung+Makan...
#
#                                                Text Rating Reviews  \
# 0                               Gendar Pecel Bu Har    4,7    (15)
# 1                              Gendar pecel Mbak Ni    5,0     (1)
# 2                           Gendar Pecel Bu Sukirah    5,0     (2)
# 3                          Gendar Pecel " Bu Mardi"    5,0     (3)
# 4  Warung Makan Gendar Pecel, Aneka Sayur & Minuman    5,0     (4)
#
#        Kategori                                            Address  Website  \
# 0  Gendar Pecel  \nJl. Walanda Maramis No.92-90, Nusukan, Kec....      NaN
# 1  Gendar Pecel  \nJl. Ponconoko 3 No.4, Tipes, Kec. Serengan,...      NaN
# 2  Gendar Pecel  \nFR2Q+C9H, Mojosongo, Kec. Jebres, Kota Sura...      NaN
# 3  Gendar Pecel  \nJl. Srigunting No.10, Kerten, Kec. Laweyan,...      NaN
# 4  Gendar Pecel  \nCR69+9JH, Jl. Babar Layar VI, Danukusuman, ...      NaN
#
#      Phone_Number  Photo                                      Opening_Hours  \
# 0             NaN    NaN  Minggu\n10.00–15.00\nSenin\n10.00–15.00\nSelas...
# 1  0896-9179-2167    NaN  Minggu\n08.30–14.30\nSenin\n08.30–14.30\nSelas...
# 2  0856-4769-1915    NaN  Minggu\n09.00–15.00\nSenin\n09.00–15.00\nSelas...
# 3             NaN    NaN                                                NaN
# 4             NaN    NaN  Minggu\n08.00–15.00\nSenin\n08.00–15.00\nSelas...
#
#    Range_Harga  Deskripsi_Toko  Latitude   Longitude
# 0          NaN             NaN -7.547476  110.759734
# 1          NaN             NaN -7.547476  110.759734
# 2          NaN             NaN -7.547476  110.759734
# 3          NaN             NaN -7.559943  110.721156
# 4          NaN             NaN -7.559943  110.721156

# %%
df_asle.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Ronde...
# 1  https://www.google.com/maps/place/Wedang+Ronde...
# 2  https://www.google.com/maps/place/Wedang+Asle+...
# 3  https://www.google.com/maps/place/Sego+Liwet+B...
# 4  https://www.google.com/maps/place/Wedang+Ronde...
#
#                                    Text Rating Reviews     Kategori  \
# 0               Wedang Ronde Asle Laris    4,9    (33)  Wedang Asle
# 1             Wedang Ronde Asle Pak Mar    4,6   (402)  Wedang Asle
# 2                   Wedang Asle De Topo    5,0     (3)  Wedang Asle
# 3  Sego Liwet Bu Par, Wedang Asle Ronde    4,5    (41)  Wedang Asle
# 4       Wedang Ronde dan Asle Pak Usman    5,0     (6)  Wedang Asle
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Agus Salim No.29-33, Sondakan, Kec. Law...      NaN  0813-2939-7120
# 1  \nManahan, Kec. Banjarsari, Kota Surakarta, J...      NaN  0815-4810-6867
# 2  \nJl. Kamandungan No.2, Baluwarti, Kec. Ps. K...      NaN  0858-6742-6235
# 3  \nJl. Yos Sudarso No.93, Gajahan, Kec. Ps. Kl...      NaN  0878-2816-3193
# 4  \nFR73+RH4, Jl. Tarumanegara I, Banyuanyar, K...      NaN             NaN
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Sabtu\n00.00–12.00\n18.00–00.00\nMinggu\n00.00...  Rp 1–25.000
# 1    NaN  Minggu\n17.00–23.00\nSenin\n17.00–23.00\nSelas...  Rp 1–25.000
# 2    NaN  Minggu\n14.00–21.00\nSenin\n14.00–21.00\nSelas...          NaN
# 3    NaN                                                NaN  Rp 1–25.000
# 4    NaN  Minggu\n16.30–23.00\nSenin\n16.30–23.00\nSelas...          NaN
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.566556  110.720762
# 1            NaN -7.566556  110.720762
# 2            NaN -7.577369  110.756174
# 3            NaN -7.577369  110.756174
# 4            NaN -7.577369  110.756174

# %%
df_eskapal.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Es+Kapal/@-7...
# 1  https://www.google.com/maps/place/Es+Kapal+Bat...
# 2  https://www.google.com/maps/place/ES+KAPAL+ASL...
# 3  https://www.google.com/maps/place/Es+Kapal+Pin...
# 4  https://www.google.com/maps/place/Es+Kapal+Dep...
#
#                                             Text Rating Reviews  Kategori  \
# 0                                       Es Kapal    4,7   (800)  Es Kapal
# 1                            Es Kapal Batik Solo    4,5    (85)  Es Kapal
# 2          ES KAPAL ASLI SRIWEDARI 07 ISKANDARIA    4,6   (528)  Es Kapal
# 3                          Es Kapal Pinggir Kali    4,7    (15)  Es Kapal
# 4  Es Kapal Depan Museum Keris Stadion Sriwedari    4,7    (17)  Es Kapal
#
#                                              Address  Website    Phone_Number  \
# 0  \nJl. Dr. Rajiman No.353, Panularan, Kec. Law...      NaN             NaN
# 1  \nCRRC+H6R, Jl. Bintan, Ketelan, Kec. Banjars...      NaN  0857-2807-7714
# 2  \nJl. Bhayangkara, Sriwedari, Kec. Laweyan, K...      NaN  0813-3617-0095
# 3  \nJl. Bhayangkara No.16, Sriwedari, Kec. Lawe...      NaN             NaN
# 4  \nJl Bayangkara, gang Jembatan Depan Museum K...      NaN   0856-2825-766
#
#    Photo                                      Opening_Hours  Range_Harga  \
# 0    NaN  Minggu\n10.00–18.00\nSenin\n10.00–18.00\nSelas...  Rp 1–25.000
# 1    NaN  Minggu\n10.00–16.00\nSenin\n10.00–16.00\nSelas...          NaN
# 2    NaN  Minggu\n08.30–17.00\nSenin\n08.30–17.00\nSelas...  Rp 1–25.000
# 3    NaN                                                NaN          NaN
# 4    NaN  Minggu\n10.30–18.00\nSenin\n10.30–18.00\nSelas...  Rp 1–25.000
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.563082  110.778197
# 1             NaN -7.563082  110.778197
# 2             NaN -7.563082  110.778197
# 3             NaN -7.563082  110.778197
# 4             NaN -7.563082  110.778197

# %%
df_esgempol.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Es+Gempol+Pl...
# 1  https://www.google.com/maps/place/Warung+Makan...
# 2  https://www.google.com/maps/place/ES+GEMPOL+PL...
# 3  https://www.google.com/maps/place/Es+Gempol+Pl...
# 4  https://www.google.com/maps/place/Es+Gempol+Pl...
#
#                                                 Text Rating Reviews  \
# 0              Es Gempol Pleret & Es Dawet Mbak Lena    3,9    (34)
# 1  Warung Makan Es Gempol Pleret dan Mie Thoprak ...    4,5   (969)
# 2       ES GEMPOL PLERET 36, ES TEH JUMBO,MIE TOPRAK    4,9    (12)
# 3                      Es Gempol Pleret Abang Muscle    NaN     NaN
# 4                            Es Gempol Pleret Pak TW    4,8     (4)
#
#            Kategori                                            Address  \
# 0  Es Gempol Pleret  \nCRGC+M7J, Jalan Gatot Subroto, Singosaren P...
# 1  Es Gempol Pleret  \nCRH3+XV2, Jl. Dr. Wahidin, Purwosari, Kec. ...
# 2  Es Gempol Pleret  \n9RR6+258, Jl. Solo Permai, Dusun III, Lange...
# 3  Es Gempol Pleret  \nJl. Slamet Riyadi No.16, Kp. Baru, Kec. Ps....
# 4  Es Gempol Pleret  \nJl. Temugiring Raya, Pajang, Kec. Laweyan, ...
#
#    Website    Phone_Number  Photo  \
# 0      NaN  0856-4747-9095    NaN
# 1      NaN             NaN    NaN
# 2      NaN  0852-2976-3220    NaN
# 3      NaN             NaN    NaN
# 4      NaN             NaN    NaN
#
#                                        Opening_Hours  Range_Harga  \
# 0  Sabtu\n10.00–21.00\nMinggu\n10.00–21.00\nSenin...          NaN
# 1  Sabtu\n10.00–16.00\nMinggu\n10.00–16.00\nSenin...  Rp 1–25.000
# 2  Sabtu\n09.30–04.30\nMinggu\n10.05–16.05\nSenin...          NaN
# 3                                                NaN          NaN
# 4  Sabtu\n09.30–15.30\nMinggu\n09.30–15.30\nSenin...          NaN
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.584803  110.762066
# 1             NaN -7.570113  110.732544
# 2             NaN -7.609994  110.738384
# 3             NaN -7.571514  110.755659
# 4             NaN -7.559615  110.706676

# %%
df_dawettelasih.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Dawet+Telasi...
# 1  https://www.google.com/maps/place/Es+Dawet+Tel...
# 2  https://www.google.com/maps/place/Es+Dawet+Tla...
# 3  https://www.google.com/maps/place/Es+Dawet+Tel...
# 4  https://www.google.com/maps/place/Es+Dawet+Tel...
#
#                                              Text Rating Reviews  \
# 0       Dawet Telasih Bu Dermi Pasar Gede (PUSAT)    4,3   (956)
# 1  Es Dawet Telasih "Bu Dermi" Cabang Pasar Gedhe    4,7    (81)
# 2                          Es Dawet Tlasih Bu HAR    4,8    (10)
# 3            Es Dawet Telasih Khas Solo bang jeks    4,5    (13)
# 4                       Es Dawet Telasih Bu Dermi    4,5   (374)
#
#            Kategori                                            Address  \
# 0  Es Dawet Telasih  \nPasar Gedhe Hardjonagoro, Jl. Jend. Urip Su...
# 1  Es Dawet Telasih  \nKetelan, Kec. Banjarsari, Kota Surakarta, J...
# 2  Es Dawet Telasih  \nJl. Moh. Husni Thamrin No.7, Manahan, Kec. ...
# 3  Es Dawet Telasih  \nKedung Lumbu, Kec. Ps. Kliwon, Kota Surakar...
# 4  Es Dawet Telasih  \nJl. Ir. Juanda, Gandekan, Kec. Jebres, Kota...
#
#    Website    Phone_Number  Photo  \
# 0      NaN   0812-2650-302    NaN
# 1      NaN  0821-3394-0171    NaN
# 2      NaN  0821-1711-9303    NaN
# 3      NaN  0877-7170-2323    NaN
# 4      NaN    0811-265-160    NaN
#
#                                        Opening_Hours  Range_Harga  \
# 0  Senin\n08.00–14.30\nSelasa\n08.00–14.30\nRabu\...  Rp 1–25.000
# 1                                                NaN  Rp 1–25.000
# 2                                                NaN          NaN
# 3  Senin\n10.00–17.00\nSelasa\n10.00–17.00\nRabu\...  Rp 1–25.000
# 4  Senin\n09.00–16.00\nSelasa\n09.00–16.00\nRabu\...  Rp 1–25.000
#
#    Deskripsi_Toko  Latitude   Longitude
# 0             NaN -7.568155  110.819250
# 1             NaN -7.564657  110.800961
# 2             NaN -7.554078  110.782224
# 3             NaN -7.575317  110.809584
# 4             NaN -7.569008  110.822312

# %%
df_brambangasem.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Brambang+Ase...
# 1  https://www.google.com/maps/place/Rujak,+Lotis...
# 2  https://www.google.com/maps/place/Warung+mBah+...
# 3  https://www.google.com/maps/place/Bakmi+Toprak...
# 4  https://www.google.com/maps/place/warung+bramb...
#
#                                                 Text Rating Reviews  \
# 0                                      Brambang Asem    4,2    (30)
# 1               Rujak, Lotis & Brambang Asem Yu Tari    4,7    (71)
# 2  Warung mBah Ponco Tipes Solo (Pecel, Gudangan,...    5,0     (6)
# 3              Bakmi Toprak & Brambang Asem MBAH SAR    4,7    (74)
# 4           warung brambang asem,& jenang mbak niken    NaN     NaN
#
#         Kategori                                            Address  Website  \
# 0  Brambang Asem  \nCQV9+6JW, Jalan Garuda Mas Pabelan Kartasur...      NaN
# 1  Brambang Asem  \nJl. Gatot Subroto No.42, Kemlayan, Kec. Ser...      NaN
# 2  Brambang Asem  \nJl Wijaya Kusuma - Tipes RT 005 RW 014 Tipe...      NaN
# 3  Brambang Asem  \nJl. Pringgading II, Setabelan, Kec. Banjars...      NaN
# 4  Brambang Asem  \nJl. Kali Kampar No.1, Jagalan, Kec. Jebres,...      NaN
#
#      Phone_Number  Photo                                      Opening_Hours  \
# 0  0822-4085-5412    NaN  Sabtu\n09.00–20.00\nMinggu\n09.00–20.00\nSenin...
# 1  0851-0080-3492    NaN  Sabtu\n10.00–16.00\nMinggu\n10.00–16.00\nSenin...
# 2  0858-6778-0891    NaN  Sabtu\n17.00–23.00\nMinggu\nTutup\nSenin\n17.0...
# 3  0812-2568-0428    NaN  Sabtu\nTutup\nMinggu\nTutup\nSenin\n08.00–14.0...
# 4             NaN    NaN  Sabtu\n10.30–15.00\nMinggu\nTutup\nSenin\n10.3...
#
#   Range_Harga  Deskripsi_Toko  Latitude   Longitude
# 0         NaN             NaN -7.556896  110.624880
# 1         NaN             NaN -7.556896  110.624880
# 2         NaN             NaN -7.556896  110.624880
# 3         NaN             NaN -7.556896  110.624880
# 4         NaN             NaN -7.566114  110.700658

# %% [markdown]
# ## 2. Assesing

# %%
df_all = pd.concat([df_wedanguwuh, df_timlo, df_tahok, df_soto, df_serabi, df_selat,
                    df_segoliwet, df_satekere, df_satebuntel, df_lenjongan, df_gudeg,
                    df_gendarpecel, df_asle, df_eskapal, df_esgempol, df_dawettelasih,
                    df_brambangasem], ignore_index=True)
df_all.rename(columns={"Text" : "Shop_name"}, inplace=True)
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        709 non-null    object
#  1   Shop_name       709 non-null    object
#  2   Rating          663 non-null    object
#  3   Reviews         663 non-null    object
#  4   Kategori        709 non-null    object
#  5   Address         708 non-null    object
#  6   Website         1 non-null      object
#  7   Phone_Number    494 non-null    object
#  8   Photo           0 non-null      float64
#  9   Opening_Hours   605 non-null    object
#  10  Range_Harga     355 non-null    object
#  11  Deskripsi_Toko  10 non-null     object
#  12  Latitude        709 non-null    float64
#  13  Longitude       709 non-null    float64
# dtypes: float64(3), object(11)
# memory usage: 77.7+ KB

# %% [markdown]
# **Insight**:
# 1. Terdapat beberapa kesalahan tipe data
# 2. Terdapat field yang seluruhnya null

# %%
df_all.isnull().sum()
# Out:
# Page_URL            0
# Shop_name           0
# Rating             46
# Reviews            46
# Kategori            0
# Address             1
# Website           708
# Phone_Number      215
# Photo             709
# Opening_Hours     104
# Range_Harga       354
# Deskripsi_Toko    699
# Latitude            0
# Longitude           0
# dtype: int64

# %%
df_all.duplicated().sum()
df_all['Shop_name'].duplicated().sum()
# Out:
# 101

# %%
df_all = df_all.drop_duplicates(subset='Shop_name', keep='first')
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        608 non-null    object
#  1   Shop_name       608 non-null    object
#  2   Rating          566 non-null    object
#  3   Reviews         566 non-null    object
#  4   Kategori        608 non-null    object
#  5   Address         607 non-null    object
#  6   Website         1 non-null      object
#  7   Phone_Number    422 non-null    object
#  8   Photo           0 non-null      float64
#  9   Opening_Hours   514 non-null    object
#  10  Range_Harga     294 non-null    object
#  11  Deskripsi_Toko  9 non-null      object
#  12  Latitude        608 non-null    float64
#  13  Longitude       608 non-null    float64
# dtypes: float64(3), object(11)
# memory usage: 71.2+ KB

# %% [markdown]
# ## 3. Cleaning **Data**

# %% [markdown]
# ### Memperbaiki Field Rating

# %%
df_all['Rating'] = df_all['Rating'].apply(lambda x: f"{x}".replace(',', '.')).astype(float)
df_all["Rating"] = df_all["Rating"].fillna(0)

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        608 non-null    object
#  1   Shop_name       608 non-null    object
#  2   Rating          608 non-null    float64
#  3   Reviews         566 non-null    object
#  4   Kategori        608 non-null    object
#  5   Address         607 non-null    object
#  6   Website         1 non-null      object
#  7   Phone_Number    422 non-null    object
#  8   Photo           0 non-null      float64
#  9   Opening_Hours   514 non-null    object
#  10  Range_Harga     294 non-null    object
#  11  Deskripsi_Toko  9 non-null      object
#  12  Latitude        608 non-null    float64
#  13  Longitude       608 non-null    float64
# dtypes: float64(4), object(10)
# memory usage: 71.2+ KB

# %% [markdown]
# **Insight**:
# 1. Mengganti tanda koma menjadi titik
# 2. Merubah tipe data menjadi float
# 3. Mengisi missing value dengan nilai 0

# %% [markdown]
# ### Memperbaiki Field Reviews

# %%
df_all["Reviews"] = df_all["Reviews"].astype(str)
df_all["Reviews"] = df_all["Reviews"].replace('nan','(0)') #mengganti nilai string kosong menjadi (0)

def numeric_review(text):
  result=re.sub(r"[()]", "", text)
  integer_result = int(result.replace('.', ''))
  return integer_result

df_all["Reviews"] = df_all["Reviews"].apply(numeric_review) #menghapus tanda kurung, menghilangkan tanda titik, dan merubah ke integer
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        608 non-null    object
#  1   Shop_name       608 non-null    object
#  2   Rating          608 non-null    float64
#  3   Reviews         608 non-null    int64
#  4   Kategori        608 non-null    object
#  5   Address         607 non-null    object
#  6   Website         1 non-null      object
#  7   Phone_Number    422 non-null    object
#  8   Photo           0 non-null      float64
#  9   Opening_Hours   514 non-null    object
#  10  Range_Harga     294 non-null    object
#  11  Deskripsi_Toko  9 non-null      object
#  12  Latitude        608 non-null    float64
#  13  Longitude       608 non-null    float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 71.2+ KB

# %% [markdown]
# **Insight**:
# 1. Mengisi missing value dengan nilai 0
# 2. Mengambil nilai int dari reviews
# 3. Merubah tipe data menjadi int
# 4. Menghilangkan tanda kurung

# %%
df_all['Reviews'][0]
# Out:
# 5

# %%
df_all_sort_rating = df_all.sort_values(by=['Rating','Reviews'], ascending=False)[:10]
df_all_sort_rating.head()
# Out:
#                                               Page_URL  \
# 309  https://www.google.com/maps/place/Warung+Selat...
# 17   https://www.google.com/maps/place/Wedang+Uwuh+...
# 610  https://www.google.com/maps/place/GUDEG+PLENGK...
# 8    https://www.google.com/maps/place/Wedang+Jahe+...
# 693  https://www.google.com/maps/place/ES+DAWET+AYU...
#
#                                     Shop_name  Rating  Reviews  \
# 309              Warung Selat & Sop "LEZATIE"     5.0      173
# 17                             Wedang Uwuh JD     5.0       33
# 610                      GUDEG PLENGKUNG SOLO     5.0       30
# 8    Wedang Jahe Merah Keraton Cabang Coyudan     5.0       26
# 693                 ES DAWET AYU SOLO BALAPAN     5.0       25
#
#              Kategori                                            Address  \
# 309             Selat  \nJl. Untung Suropati No.167, Sangkrah, Kec. ...
# 17        Wedang Uwuh  \nJurang Kambil, RT.01/RW.4, Jurangkambil, Je...
# 610             Gudeg  \nPerum Graha Mitra Berseri, Blok O satu, Won...
# 8         Wedang Uwuh  \nJl. DR. Radjiman No.101, Kemlayan, Kec. Ser...
# 693  Es Dawet Telasih  \nJl. Walter Monginsidi, Kestalan, Kec. Banja...
#
#     Website    Phone_Number  Photo  \
# 309     NaN  0821-3604-8048    NaN
# 17      NaN  0813-2558-6053    NaN
# 610     NaN  0823-2832-2678    NaN
# 8       NaN             NaN    NaN
# 693     NaN  0858-7913-5881    NaN
#
#                                          Opening_Hours  Range_Harga  \
# 309  Senin\n09.00–15.30\nSelasa\n09.00–15.30\nRabu\...  Rp 1–25.000
# 17   Senin\n08.00–22.00\nSelasa\n08.00–22.00\nRabu\...          NaN
# 610                                                NaN          NaN
# 8    Senin\n18.00–00.00\nSelasa\nTutup\nRabu\n18.00...  Rp 1–25.000
# 693  Senin\n09.00–16.00\nSelasa\n09.00–16.00\nRabu\...          NaN
#
#     Deskripsi_Toko  Latitude   Longitude
# 309            NaN -7.580194  110.768192
# 17             NaN -7.515739  110.780665
# 610            NaN -7.572865  110.688846
# 8              NaN -7.547894  110.730811
# 693            NaN -7.557286  110.804599

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        608 non-null    object
#  1   Shop_name       608 non-null    object
#  2   Rating          608 non-null    float64
#  3   Reviews         608 non-null    int64
#  4   Kategori        608 non-null    object
#  5   Address         607 non-null    object
#  6   Website         1 non-null      object
#  7   Phone_Number    422 non-null    object
#  8   Photo           0 non-null      float64
#  9   Opening_Hours   514 non-null    object
#  10  Range_Harga     294 non-null    object
#  11  Deskripsi_Toko  9 non-null      object
#  12  Latitude        608 non-null    float64
#  13  Longitude       608 non-null    float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 87.4+ KB

# %% [markdown]
# **Menghapus kolom yang tidak diperlukan**
# 1. Menghapus kolom website
# 2. Menghapus kolom photo

# %%
df_all = df_all.drop(['Website', 'Photo'], axis = 1 )

# %%
# df_all["Address"] = df_all["Address"].apply(lambda x: x[2:])
# df_all["Address"].apply(lambda x: print(x))
df_all["Address"]
# Out:
# 0      \nMutihan rt 04 rw 1, Surakarta, Sondakan, Ke...
# 1      \nJl. Letjen Suprapto No.76c, Sumber, Kec. Ba...
# 2      \nJl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kl...
# 3      \nJl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec...
# 4      \nJl. Reksoniten No.20, Gajahan, Kec. Ps. Kli...
#                              ...
# 704    \nFR47+X2FJl, Jl. Samudra Pasai, RT.05/RW.01,...
# 705    \nJl. Durian No.25, Wungusari, Gayam, Kec. Su...
# 706    \npringgolayan rt02/08, Tipes, Kec. Serengan,...
# 707    \nJl. Kebangkitan Nasional No.60, Penumping, ...
# 708    \ndepan pos, Jl. Kahar Muzakir, RT.05/RW.06, ...
# Name: Address, Length: 608, dtype: object

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 0 to 708
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        608 non-null    object
#  1   Shop_name       608 non-null    object
#  2   Rating          608 non-null    float64
#  3   Reviews         608 non-null    int64
#  4   Kategori        608 non-null    object
#  5   Address         607 non-null    object
#  6   Phone_Number    422 non-null    object
#  7   Opening_Hours   514 non-null    object
#  8   Range_Harga     294 non-null    object
#  9   Deskripsi_Toko  9 non-null      object
#  10  Latitude        608 non-null    float64
#  11  Longitude       608 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 77.9+ KB

# %%
df_tahok["Kategori"].value_counts()
# Out:
# Kategori
# Tahok    7
# Name: count, dtype: int64

# %% [markdown]
# ### Memperbaiki field Address

# %%
# Menghapus simbol-simbol yang tidak perlu di Address
def clean_address(address):
  if pd.isna(address):
    return address
  address = address.replace('\n', '').replace('\t', '').replace('\r', '').replace('','')
  address = re.sub(r'\s+', ' ', address).strip()
  return address
df_all["Address"] = df_all["Address"].apply(clean_address)

# %%
df_all["Address"]
# Out:
# 0      Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...
# 1      Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...
# 2      Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...
# 3      Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...
# 4      Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...
#                              ...
# 704    FR47+X2FJl, Jl. Samudra Pasai, RT.05/RW.01, Ka...
# 705    Jl. Durian No.25, Wungusari, Gayam, Kec. Sukoh...
# 706    pringgolayan rt02/08, Tipes, Kec. Serengan, Ko...
# 707    Jl. Kebangkitan Nasional No.60, Penumping, Kec...
# 708    depan pos, Jl. Kahar Muzakir, RT.05/RW.06, Moj...
# Name: Address, Length: 608, dtype: object

# %%
# Menghapus address yang kosong
df_all = df_all.dropna(subset=['Address'])
empty_address_count = df_all["Address"].isnull().sum()
print(f"Number of empty addresses after dropping NaN: {empty_address_count}")
# Out:
# Number of empty addresses after dropping NaN: 0

# %% [markdown]
# ### Memperbaiki field phone number

# %%
df_all["Phone_Number"] = df_all["Phone_Number"].fillna(0).astype(str)
df_all["Phone_Number"] = df_all["Phone_Number"].apply(lambda num: num.replace("-", ""))
# Out:
# <ipython-input-36-b07fe1f82268>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Phone_Number"] = df_all["Phone_Number"].fillna(0).astype(str)
# <ipython-input-36-b07fe1f82268>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Phone_Number"] = df_all["Phone_Number"].apply(lambda num: num.replace("-", ""))

# %% [markdown]
# **Insight**:
# 1. Mengisi missing value dengan nilai 0
# 2. Menghapus tanda (-)

# %%
df_all['Phone_Number']
# Out:
# 0      082324006000
# 1      085641727445
# 2      081229070267
# 3      081578614885
# 4      089608149211
#            ...
# 704               0
# 705               0
# 706    081390407718
# 707    085713063229
# 708    083107764229
# Name: Phone_Number, Length: 607, dtype: object

# %% [markdown]
# ### Memperbaiki field opening hours

# %%
def parse_opening_hours(text):
    """Parses opening hours text into a dictionary.

    Args:
        text: The text containing the opening hours information.

    Returns:
        A dictionary where keys are days of the week and values are lists of opening hours.
    """

    opening_hours = {}
    lines = text.strip().split('\n')

    i = 0
    while i < len(lines):
        day = lines[i].strip()
        hours = []

        # Loop untuk menangani beberapa rentang waktu pada hari yang sama
        i += 1
        while i < len(lines) and not lines[i].startswith(('Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu')):
            hours.append(lines[i].strip())
            i += 1

        opening_hours[day] = hours

    return opening_hours

# %%
df_all["Opening_Hours"].isna().sum()
# Out:
# 93

# %%
opening_hours_terbanyak = df_all["Opening_Hours"].value_counts().index[1]
print(opening_hours_terbanyak)
# Out:
# Minggu
# Buka 24 jam
# Senin
# Buka 24 jam
# Selasa
# Buka 24 jam
# Rabu
# Buka 24 jam
# Kamis
# Buka 24 jam
# Jumat
# Buka 24 jam
# Sabtu
# Buka 24 jam

# %%
df_all["Opening_Hours"] = df_all["Opening_Hours"].fillna(opening_hours_terbanyak)
# Out:
# <ipython-input-41-a8916437720b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Opening_Hours"] = df_all["Opening_Hours"].fillna(opening_hours_terbanyak)

# %%
df_all["Opening_Hours"] = df_all["Opening_Hours"].apply(parse_opening_hours)
# Out:
# <ipython-input-42-0c0f676b0be2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Opening_Hours"] = df_all["Opening_Hours"].apply(parse_opening_hours)

# %% [markdown]
# **Insight**:
# 1. Mengisi missing value dengan nilai buka yang paling banyak dan sesuai
# 2. Mengganti format data menjadi dictionary dengan hari sebagai key dan jam sebagai value dalam list

# %% [markdown]
# ### Memperbaiki field range harga

# %%
df_all["Range_Harga"].isna().sum()
# Out:
# 313

# %%
df_all["Range_Harga"] = df_all["Range_Harga"].fillna("Rp 1–25 rb")
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda x: x.replace("\xa0", " "))
# Out:
# <ipython-input-44-fdda786643dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Range_Harga"] = df_all["Range_Harga"].fillna("Rp 1–25 rb")
# <ipython-input-44-fdda786643dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda x: x.replace("\xa0", " "))

# %%
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda price: price.replace("$", "Rp 1–25 rb"))
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda price: price.replace("$$", "Rp 1–25 rb"))
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda price: price.replace("Rp 1-50.000", "Rp 1–50 rb"))
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda price: price.replace("Rp 1–25.000", "Rp 1–25 rb"))
df_all["Range_Harga"] = df_all["Range_Harga"].apply(lambda x: x.replace("Rp 1–25 rbRp 1–25 rb", "Rp 1–25 rb"))

# %%
df_all.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Uwuh+...
# 1  https://www.google.com/maps/place/Rajanya+JAHE...
# 2  https://www.google.com/maps/place/Wedang+uwuh+...
# 3  https://www.google.com/maps/place/Wedang+uwuh+...
# 4  https://www.google.com/maps/place/wedang+uwuh+...
#
#                                  Shop_name  Rating  Reviews     Kategori  \
# 0              Wedang Uwuh Solo - Pak Aden     4.6        5  Wedang Uwuh
# 1  Rajanya JAHE REMPAH wedhang uwuh Sumber     4.6       32  Wedang Uwuh
# 2                Wedang uwuh jelantik solo     5.0        1  Wedang Uwuh
# 3                     Wedang uwuh mbok tuo     4.9       14  Wedang Uwuh
# 4                          wedang uwuh sya     4.7        3  Wedang Uwuh
#
#                                              Address  Phone_Number  \
# 0  Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...  082324006000
# 1  Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...  085641727445
# 2  Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...  081229070267
# 3  Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...  081578614885
# 4  Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...  089608149211
#
#                                        Opening_Hours Range_Harga  \
# 0  {'Senin': ['08.00–20.00'], 'Selasa': ['08.00–2...  Rp 1–25 rb
# 1  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb
# 2  {'Senin': ['Buka 24 jam'], 'Selasa': ['Buka 24...  Rp 1–25 rb
# 3  {'Senin': ['07.00–19.00'], 'Selasa': ['07.00–1...  Rp 1–25 rb
# 4  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb
#
#   Deskripsi_Toko  Latitude   Longitude
# 0            NaN -7.566731  110.716919
# 1            NaN -7.566731  110.716919
# 2            NaN -7.576765  110.768229
# 3            NaN -7.547894  110.730811
# 4            NaN -7.547894  110.730811

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 607 entries, 0 to 708
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Page_URL        607 non-null    object
#  1   Shop_name       607 non-null    object
#  2   Rating          607 non-null    float64
#  3   Reviews         607 non-null    int64
#  4   Kategori        607 non-null    object
#  5   Address         607 non-null    object
#  6   Phone_Number    607 non-null    object
#  7   Opening_Hours   607 non-null    object
#  8   Range_Harga     607 non-null    object
#  9   Deskripsi_Toko  9 non-null      object
#  10  Latitude        607 non-null    float64
#  11  Longitude       607 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 61.6+ KB

# %%
df_all.isna().sum()
# Out:
# Page_URL            0
# Shop_name           0
# Rating              0
# Reviews             0
# Kategori            0
# Address             0
# Phone_Number        0
# Opening_Hours       0
# Range_Harga         0
# Deskripsi_Toko    598
# Latitude            0
# Longitude           0
# dtype: int64

# %% [markdown]
# ### Identifikasi Eco Friendly

# %%
df_all["Kategori"].value_counts()
# Out:
# Kategori
# Sego Liwet          74
# Soto                70
# Serabi              63
# Selat               62
# Wedang Uwuh         61
# Sate Kere           61
# Sate Buntel         53
# Timlo               44
# Gudeg               30
# Gendar Pecel        29
# Es Dawet Telasih    19
# Wedang Asle         12
# Brambang Asem       10
# Tahok                7
# Es Kapal             5
# Es Gempol Pleret     5
# Lenjongan            2
# Name: count, dtype: int64

# %%
eco_friendly =['Gudeg', 'Brambang Asem', 'Gendar Pecel', 'Sate Kere', 'Sate Buntel', 'Sego Liwet', 'Serabi', 'Lenjongan']
df_all["Eco_Friendly"] = df_all["Kategori"].apply(lambda x: 1 if x in eco_friendly else 0)

# %%
df_all.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Uwuh+...
# 1  https://www.google.com/maps/place/Rajanya+JAHE...
# 2  https://www.google.com/maps/place/Wedang+uwuh+...
# 3  https://www.google.com/maps/place/Wedang+uwuh+...
# 4  https://www.google.com/maps/place/wedang+uwuh+...
#
#                                  Shop_name  Rating  Reviews     Kategori  \
# 0              Wedang Uwuh Solo - Pak Aden     4.6        5  Wedang Uwuh
# 1  Rajanya JAHE REMPAH wedhang uwuh Sumber     4.6       32  Wedang Uwuh
# 2                Wedang uwuh jelantik solo     5.0        1  Wedang Uwuh
# 3                     Wedang uwuh mbok tuo     4.9       14  Wedang Uwuh
# 4                          wedang uwuh sya     4.7        3  Wedang Uwuh
#
#                                              Address  Phone_Number  \
# 0  Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...  082324006000
# 1  Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...  085641727445
# 2  Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...  081229070267
# 3  Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...  081578614885
# 4  Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...  089608149211
#
#                                        Opening_Hours Range_Harga  \
# 0  {'Senin': ['08.00–20.00'], 'Selasa': ['08.00–2...  Rp 1–25 rb
# 1  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb
# 2  {'Senin': ['Buka 24 jam'], 'Selasa': ['Buka 24...  Rp 1–25 rb
# 3  {'Senin': ['07.00–19.00'], 'Selasa': ['07.00–1...  Rp 1–25 rb
# 4  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb
#
#   Deskripsi_Toko  Latitude   Longitude  Eco_Friendly
# 0            NaN -7.566731  110.716919             0
# 1            NaN -7.566731  110.716919             0
# 2            NaN -7.576765  110.768229             0
# 3            NaN -7.547894  110.730811             0
# 4            NaN -7.547894  110.730811             0

# %% [markdown]
# ### Food with Weather Category

# %%
food_weather={
    'Dingin/Panas': ['Serabi', 'Sate Kere', 'Sate Buntel', 'Gudeg', 'Gendar Pecel', 'Brambang Asem', 'Lenjongan'],
    'Dingin': ['Wedang Uwuh', 'Wedang Asle', 'Tahok', 'Timlo', 'Soto', 'Selat', 'Sego Liwet'],
    'Panas' : ['Es Gempol Pleret', 'Es Kapal', 'Es Dawet Telasih']
    }

def categorize_weather(food_item):
    for weather, foods in food_weather.items():
        if food_item in foods:
            return weather
    return None

df_all['Categorize_Weather'] = df_all['Kategori'].apply(categorize_weather)

# %%
df_all.head(500)
# Out:
#                                               Page_URL  \
# 0    https://www.google.com/maps/place/Wedang+Uwuh+...
# 1    https://www.google.com/maps/place/Rajanya+JAHE...
# 2    https://www.google.com/maps/place/Wedang+uwuh+...
# 3    https://www.google.com/maps/place/Wedang+uwuh+...
# 4    https://www.google.com/maps/place/wedang+uwuh+...
# ..                                                 ...
# 589  https://www.google.com/maps/place/Lenjongan/@-...
# 590  https://www.google.com/maps/place/Lenjongan+Yu...
# 591  https://www.google.com/maps/place/Gudeg+Solo+M...
# 592  https://www.google.com/maps/place/Gudeg+Mbak+Y...
# 594  https://www.google.com/maps/place/Gudeg+Solo+J...
#
#                                    Shop_name  Rating  Reviews     Kategori  \
# 0                Wedang Uwuh Solo - Pak Aden     4.6        5  Wedang Uwuh
# 1    Rajanya JAHE REMPAH wedhang uwuh Sumber     4.6       32  Wedang Uwuh
# 2                  Wedang uwuh jelantik solo     5.0        1  Wedang Uwuh
# 3                       Wedang uwuh mbok tuo     4.9       14  Wedang Uwuh
# 4                            wedang uwuh sya     4.7        3  Wedang Uwuh
# ..                                       ...     ...      ...          ...
# 589                                Lenjongan     4.0        1    Lenjongan
# 590                Lenjongan Yu Sum Ps.Gedhe     4.4       51    Lenjongan
# 591                Gudeg Solo Mbak Sulandari     4.7      589        Gudeg
# 592                           Gudeg Mbak Yus     4.4     1136        Gudeg
# 594                       Gudeg Solo Javenir     4.4      422        Gudeg
#
#                                                Address    Phone_Number  \
# 0    Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...    082324006000
# 1    Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...    085641727445
# 2    Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...    081229070267
# 3    Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...    081578614885
# 4    Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...    089608149211
# ..                                                 ...             ...
# 589  CRJ8+8QH, Sriwedari, Kec. Laweyan, Kota Suraka...               0
# 590  Jl. Jend. Urip Sumoharjo, Sudiroprajan, Kec. J...   (0271) 000000
# 591  Jl. Hasanudin No.109 C, Jawa Tengah, Kec. Banj...    082134868666
# 592  Jl. RA Kartini No.12, Timuran, Kec. Banjarsari...    081280205859
# 594  Komplek Javenir, Jl. Adi Sucipto No.48, Blukuk...  (0271) 7461795
#
#                                          Opening_Hours  Range_Harga  \
# 0    {'Senin': ['08.00–20.00'], 'Selasa': ['08.00–2...   Rp 1–25 rb
# 1    {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...   Rp 1–25 rb
# 2    {'Senin': ['Buka 24 jam'], 'Selasa': ['Buka 24...   Rp 1–25 rb
# 3    {'Senin': ['07.00–19.00'], 'Selasa': ['07.00–1...   Rp 1–25 rb
# 4    {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...   Rp 1–25 rb
# ..                                                 ...          ...
# 589  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...   Rp 1–25 rb
# 590  {'Minggu': ['07.00–17.00'], 'Senin': ['07.00–1...   Rp 1–25 rb
# 591  {'Minggu': ['08.00–16.00'], 'Senin': ['Tutup']...  Rp 25–50 rb
# 592  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 25–50 rb
# 594  {'Minggu': ['09.00–23.00'], 'Senin': ['09.00–2...  Rp 25–50 rb
#
#     Deskripsi_Toko  Latitude   Longitude  Eco_Friendly Categorize_Weather
# 0              NaN -7.566731  110.716919             0             Dingin
# 1              NaN -7.566731  110.716919             0             Dingin
# 2              NaN -7.576765  110.768229             0             Dingin
# 3              NaN -7.547894  110.730811             0             Dingin
# 4              NaN -7.547894  110.730811             0             Dingin
# ..             ...       ...         ...           ...                ...
# 589            NaN -7.569179  110.807963             1       Dingin/Panas
# 590            NaN -7.568962  110.822755             1       Dingin/Panas
# 591            NaN -7.557978  110.673642             1       Dingin/Panas
# 592            NaN -7.557978  110.673642             1       Dingin/Panas
# 594            NaN -7.557978  110.673642             1       Dingin/Panas
#
# [500 rows x 14 columns]

# %% [markdown]
# ## Export File xlsx

# %%
# from google.colab import files
# df_all.to_csv('df_all.xlsx', encoding = 'utf-8-sig')
# files.download('df_all.xlsx')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Perolehan 10 lokasi kuliner dengan rating tertinggi dan review terbanyak

# %%
df_top_10 = df_all.sort_values(by=['Rating', 'Reviews'], ascending=False).head(10)
df_top_10
# Out:
#                                               Page_URL  \
# 309  https://www.google.com/maps/place/Warung+Selat...
# 17   https://www.google.com/maps/place/Wedang+Uwuh+...
# 610  https://www.google.com/maps/place/GUDEG+PLENGK...
# 8    https://www.google.com/maps/place/Wedang+Jahe+...
# 693  https://www.google.com/maps/place/ES+DAWET+AYU...
# 221  https://www.google.com/maps/place/Serabi+Nakna...
# 303  https://www.google.com/maps/place/SELAT+MBAK+L...
# 612  https://www.google.com/maps/place/Nasi+Gudeg+B...
# 607  https://www.google.com/maps/place/GUDEG+COYUDA...
# 223  https://www.google.com/maps/place/Serabi+ngruQ...
#
#                                     Shop_name  Rating  Reviews  \
# 309              Warung Selat & Sop "LEZATIE"     5.0      173
# 17                             Wedang Uwuh JD     5.0       33
# 610                      GUDEG PLENGKUNG SOLO     5.0       30
# 8    Wedang Jahe Merah Keraton Cabang Coyudan     5.0       26
# 693                 ES DAWET AYU SOLO BALAPAN     5.0       25
# 221                             Serabi Naknan     5.0       24
# 303                            SELAT MBAK LIN     5.0       20
# 612              Nasi Gudeg Bu Puji Khas Solo     5.0       20
# 607                             GUDEG COYUDAN     5.0       19
# 223                              Serabi ngruQ     5.0       11
#
#              Kategori                                            Address  \
# 309             Selat  Jl. Untung Suropati No.167, Sangkrah, Kec. Ps....
# 17        Wedang Uwuh  Jurang Kambil, RT.01/RW.4, Jurangkambil, Jeruk...
# 610             Gudeg  Perum Graha Mitra Berseri, Blok O satu, Wonore...
# 8         Wedang Uwuh  Jl. DR. Radjiman No.101, Kemlayan, Kec. Sereng...
# 693  Es Dawet Telasih  Jl. Walter Monginsidi, Kestalan, Kec. Banjarsa...
# 221            Serabi  Pertokoan nusukan, Jl. Adi Sumarmo No.103, Nus...
# 303             Selat  Karang kidul, RT.01/RW.16, Makamhaji, Kec. Kar...
# 612             Gudeg  Tegal Mulyo, RT.03/RW.08, Pabelan, Kec. Kartas...
# 607             Gudeg  Jl. Dr. Rajiman COYUDAN No.126, Kemlayan, Kec....
# 223            Serabi  dahlian, Gg. Manggis I No.10, Ngruki, Cemani, ...
#
#      Phone_Number                                      Opening_Hours  \
# 309  082136048048  {'Senin': ['09.00–15.30'], 'Selasa': ['09.00–1...
# 17   081325586053  {'Senin': ['08.00–22.00'], 'Selasa': ['08.00–2...
# 610  082328322678  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...
# 8               0  {'Senin': ['18.00–00.00'], 'Selasa': ['Tutup']...
# 693  085879135881  {'Senin': ['09.00–16.00'], 'Selasa': ['09.00–1...
# 221   08978954908  {'Senin': ['07.00–20.00'], 'Selasa': ['07.00–2...
# 303  085866501052  {'Senin': ['08.00–17.00'], 'Selasa': ['08.00–1...
# 612   08999390757  {'Minggu': ['07.30–20.00'], 'Senin': ['07.30–2...
# 607   08112698101  {'Minggu': ['07.00–00.00'], 'Senin': ['07.00–0...
# 223  085227422398  {'Senin': ['07.30–19.30'], 'Selasa': ['08.00–1...
#
#      Range_Harga Deskripsi_Toko  Latitude   Longitude  Eco_Friendly  \
# 309   Rp 1–25 rb            NaN -7.580194  110.768192             0
# 17    Rp 1–25 rb            NaN -7.515739  110.780665             0
# 610   Rp 1–25 rb            NaN -7.572865  110.688846             1
# 8     Rp 1–25 rb            NaN -7.547894  110.730811             0
# 693   Rp 1–25 rb            NaN -7.557286  110.804599             0
# 221   Rp 1–25 rb            NaN -7.544877  110.742780             1
# 303   Rp 1–25 rb            NaN -7.566844  110.518647             0
# 612   Rp 1–25 rb            NaN -7.554392  110.611984             1
# 607  Rp 25–50 rb            NaN -7.557978  110.673642             1
# 223   Rp 1–25 rb            NaN -7.580505  110.743412             1
#
#     Categorize_Weather
# 309             Dingin
# 17              Dingin
# 610       Dingin/Panas
# 8               Dingin
# 693              Panas
# 221       Dingin/Panas
# 303             Dingin
# 612       Dingin/Panas
# 607       Dingin/Panas
# 223       Dingin/Panas

# %% [markdown]
# ## 2. Perolehan 10 lokasi kuliner dengan ...

# %%
df_eco_top_10 = df_all[df_all['Eco_Friendly'] == 1].sort_values(by=['Rating','Reviews'], ascending=False).head(10)
df_eco_top_10
# Out:
#                                               Page_URL  \
# 610  https://www.google.com/maps/place/GUDEG+PLENGK...
# 221  https://www.google.com/maps/place/Serabi+Nakna...
# 612  https://www.google.com/maps/place/Nasi+Gudeg+B...
# 607  https://www.google.com/maps/place/GUDEG+COYUDA...
# 223  https://www.google.com/maps/place/Serabi+ngruQ...
# 493  https://www.google.com/maps/place/Wedangan+Kre...
# 609  https://www.google.com/maps/place/Gudeg+Mbak+T...
# 626  https://www.google.com/maps/place/Gudeg+Jogja+...
# 484  https://www.google.com/maps/place/Sate+kere+Mb...
# 269  https://www.google.com/maps/place/Serabi+Solo+...
#
#                                              Shop_name  Rating  Reviews  \
# 610                               GUDEG PLENGKUNG SOLO     5.0       30
# 221                                      Serabi Naknan     5.0       24
# 612                       Nasi Gudeg Bu Puji Khas Solo     5.0       20
# 607                                      GUDEG COYUDAN     5.0       19
# 223                                       Serabi ngruQ     5.0       11
# 493  Wedangan Kresna & Sate Kere Solo "Lombok Rawit...     5.0       11
# 609                        Gudeg Mbak Tutik, Lojiwetan     5.0       11
# 626                               Gudeg Jogja 22 Opane     5.0       10
# 484                Sate kere Mbak Tug ( Sate Presiden)     5.0        9
# 269                                  Srabi Hitz Klewer     5.0        8
#
#       Kategori                                            Address  \
# 610      Gudeg  Perum Graha Mitra Berseri, Blok O satu, Wonore...
# 221     Serabi  Pertokoan nusukan, Jl. Adi Sumarmo No.103, Nus...
# 612      Gudeg  Tegal Mulyo, RT.03/RW.08, Pabelan, Kec. Kartas...
# 607      Gudeg  Jl. Dr. Rajiman COYUDAN No.126, Kemlayan, Kec....
# 223     Serabi  dahlian, Gg. Manggis I No.10, Ngruki, Cemani, ...
# 493  Sate Kere  Jl. A. Yani No.93, Gilingan, Kec. Banjarsari, ...
# 609      Gudeg  CRGM+V63, Jl. Kapten Mulyadi, Kedung Lumbu, Ke...
# 626      Gudeg  CRV3+W62 Stadium, Manahan, Kec. Banjarsari, Ko...
# 484  Sate Kere  Jl. RE. Martadinata No.53, Sudiroprajan, Kec. ...
# 269     Serabi  Jl. Merapi, Klewer, Sraten, Kec. Gatak, Kabupa...
#
#      Phone_Number                                      Opening_Hours  \
# 610  082328322678  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...
# 221   08978954908  {'Senin': ['07.00–20.00'], 'Selasa': ['07.00–2...
# 612   08999390757  {'Minggu': ['07.30–20.00'], 'Senin': ['07.30–2...
# 607   08112698101  {'Minggu': ['07.00–00.00'], 'Senin': ['07.00–0...
# 223  085227422398  {'Senin': ['07.30–19.30'], 'Selasa': ['08.00–1...
# 493  085790955307  {'Minggu': ['17.00–00.00'], 'Senin': ['17.00–0...
# 609             0  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...
# 626  085848544584  {'Minggu': ['09.00–01.00'], 'Senin': ['09.00–0...
# 484  087836036003  {'Minggu': ['16.00–23.00'], 'Senin': ['16.00–2...
# 269  085641952512  {'Senin': ['05.00–12.00'], 'Selasa': ['05.00–1...
#
#      Range_Harga Deskripsi_Toko  Latitude   Longitude  Eco_Friendly  \
# 610   Rp 1–25 rb            NaN -7.572865  110.688846             1
# 221   Rp 1–25 rb            NaN -7.544877  110.742780             1
# 612   Rp 1–25 rb            NaN -7.554392  110.611984             1
# 607  Rp 25–50 rb            NaN -7.557978  110.673642             1
# 223   Rp 1–25 rb            NaN -7.580505  110.743412             1
# 493   Rp 1–25 rb            NaN -7.556151  110.796085             1
# 609   Rp 1–25 rb            NaN -7.572865  110.688846             1
# 626   Rp 1–25 rb            NaN -7.563152  110.674829             1
# 484   Rp 1–25 rb            NaN -7.570300  110.797749             1
# 269   Rp 1–25 rb            NaN -7.583826  110.764218             1
#
#     Categorize_Weather
# 610       Dingin/Panas
# 221       Dingin/Panas
# 612       Dingin/Panas
# 607       Dingin/Panas
# 223       Dingin/Panas
# 493       Dingin/Panas
# 609       Dingin/Panas
# 626       Dingin/Panas
# 484       Dingin/Panas
# 269       Dingin/Panas

# %% [markdown]
# ## 3. Data 10 makanan yang cocok cuaca dingin dengan rating tertinggi

# %%
df_dingin_top_10 = df_all[df_all['Categorize_Weather'] == 'Dingin'].sort_values(by=['Rating', 'Reviews'], ascending=False).head(10)
df_dingin_top_10
# Out:
#                                               Page_URL  \
# 309  https://www.google.com/maps/place/Warung+Selat...
# 17   https://www.google.com/maps/place/Wedang+Uwuh+...
# 8    https://www.google.com/maps/place/Wedang+Jahe+...
# 303  https://www.google.com/maps/place/SELAT+MBAK+L...
# 43   https://www.google.com/maps/place/Wedangan+Mas...
# 353  https://www.google.com/maps/place/Warung+Selat...
# 30   https://www.google.com/maps/place/Wedangan+Mas...
# 36   https://www.google.com/maps/place/Wedangan+Mas...
# 113  https://www.google.com/maps/place/Tahok+Kemban...
# 660  https://www.google.com/maps/place/Wedang+Ronde...
#
#                                        Shop_name  Rating  Reviews  \
# 309                 Warung Selat & Sop "LEZATIE"     5.0      173
# 17                                Wedang Uwuh JD     5.0       33
# 8       Wedang Jahe Merah Keraton Cabang Coyudan     5.0       26
# 303                               SELAT MBAK LIN     5.0       20
# 43              Jagung Bakar Kantor Pos Mbah Mur     5.0        8
# 353                      Selat Galantin Bu Damai     5.0        8
# 30   Swarga Tropica Wedang Uwuh, Teh, dan Rempah     5.0        7
# 36                       Wedangan Ndelik Pak Bun     5.0        7
# 113                     Tahok Kembang Tahu Menco     5.0        6
# 660              Wedang Ronde dan Asle Pak Usman     5.0        6
#
#         Kategori                                            Address  \
# 309        Selat  Jl. Untung Suropati No.167, Sangkrah, Kec. Ps....
# 17   Wedang Uwuh  Jurang Kambil, RT.01/RW.4, Jurangkambil, Jeruk...
# 8    Wedang Uwuh  Jl. DR. Radjiman No.101, Kemlayan, Kec. Sereng...
# 303        Selat  Karang kidul, RT.01/RW.16, Makamhaji, Kec. Kar...
# 43   Wedang Uwuh  Galabo Kuliner Malam Solo, Jalan Jend Sudirman...
# 353        Selat  CRCQ+RFJ, Jl. RE. Martadinata, Sangkrah, Kec. ...
# 30   Wedang Uwuh  Perum tiara ardi, Jl. Melati 1 No.3, Dusun I, ...
# 36   Wedang Uwuh  CRJ2+G88, Gg. Latar Ireng 4, Bumi, Kec. Laweya...
# 113        Tahok  Jl. Menco Raya No.1, Nilagraha, Gonilan, Kec. ...
# 660  Wedang Asle  FR73+RH4, Jl. Tarumanegara I, Banyuanyar, Kec....
#
#      Phone_Number                                      Opening_Hours  \
# 309  082136048048  {'Senin': ['09.00–15.30'], 'Selasa': ['09.00–1...
# 17   081325586053  {'Senin': ['08.00–22.00'], 'Selasa': ['08.00–2...
# 8               0  {'Senin': ['18.00–00.00'], 'Selasa': ['Tutup']...
# 303  085866501052  {'Senin': ['08.00–17.00'], 'Selasa': ['08.00–1...
# 43    08122592667  {'Senin': ['16.30–23.00'], 'Selasa': ['16.30–2...
# 353  081327045438  {'Senin': ['11.00–15.00'], 'Selasa': ['11.00–1...
# 30    08886891286  {'Senin': ['08.00–16.00'], 'Selasa': ['08.00–1...
# 36   081329672281  {'Senin': ['Tutup'], 'Selasa': ['17.00–23.00']...
# 113  087788770223  {'Senin': ['06.00–21.00'], 'Selasa': ['06.00–2...
# 660             0  {'Minggu': ['16.30–23.00'], 'Senin': ['16.30–2...
#
#     Range_Harga Deskripsi_Toko  Latitude   Longitude  Eco_Friendly  \
# 309  Rp 1–25 rb            NaN -7.580194  110.768192             0
# 17   Rp 1–25 rb            NaN -7.515739  110.780665             0
# 8    Rp 1–25 rb            NaN -7.547894  110.730811             0
# 303  Rp 1–25 rb            NaN -7.566844  110.518647             0
# 43   Rp 1–25 rb            NaN -7.557129  110.694612             0
# 353  Rp 1–25 rb            NaN -7.540142  110.521980             0
# 30   Rp 1–25 rb            NaN -7.557129  110.694612             0
# 36   Rp 1–25 rb            NaN -7.557129  110.694612             0
# 113  Rp 1–25 rb            NaN -7.569240  106.995623             0
# 660  Rp 1–25 rb            NaN -7.577369  110.756174             0
#
#     Categorize_Weather
# 309             Dingin
# 17              Dingin
# 8               Dingin
# 303             Dingin
# 43              Dingin
# 353             Dingin
# 30              Dingin
# 36              Dingin
# 113             Dingin
# 660             Dingin

# %%
df_all.describe()
# Out:
#            Rating       Reviews    Latitude   Longitude  Eco_Friendly
# count  607.000000    607.000000  607.000000  607.000000    607.000000
# mean     4.282208    423.372323   -7.563622  110.649930      0.530478
# std      1.207490   1349.901384    0.023294    0.406081      0.499482
# min      0.000000      0.000000   -7.693490  106.995623      0.000000
# 25%      4.400000      3.000000   -7.576085  110.658049      0.000000
# 50%      4.600000     23.000000   -7.557978  110.694612      1.000000
# 75%      4.900000    226.000000   -7.546742  110.775705      1.000000
# max      5.000000  15636.000000   -7.507090  110.860922      1.000000

# %%
import matplotlib.pyplot as plt

# Mengelompokkan data berdasarkan 'Rating' dan menghitung jumlah tiap kategori
ratings = df_all.groupby("Rating").agg({"Rating": "count"})

# Mengatur ukuran figure
figsize = (8, 5)
fig, ax = plt.subplots(figsize=figsize)

# Membuat bar chart
ratings.plot.bar(ax=ax, fontsize="large")
ax.set_ylabel("Jumlah Tempat Makan")
ax.set(title="Persebaran Data Rating")
ax.grid(axis='y', linestyle='--', alpha=0.7)  # Menambahkan grid pada sumbu Y
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")  # Memiringkan label X untuk keterbacaan

# Menampilkan plot
plt.tight_layout()  # Mengatur layout agar lebih rapi
plt.show()

# %%
df_all['Rating'].value_counts()
# Out:
# Rating
# 5.0    134
# 4.5     92
# 4.6     76
# 4.4     57
# 4.7     50
# 4.3     49
# 0.0     41
# 4.8     29
# 4.9     23
# 4.2     17
# 4.0     11
# 4.1      8
# 3.7      5
# 3.9      5
# 3.8      4
# 3.0      1
# 2.6      1
# 3.6      1
# 2.3      1
# 1.1      1
# 3.3      1
# Name: count, dtype: int64

# %% [markdown]
# ##Insight Analisis Eksplorasi
# 1. Persebaran empat makan dengan rating paling tinggi adalah 5 dengan jumlah tempat makan sebanyak 155 tempat
# 2. Pada cuaca dingin, terdapat 10 rekomendasi makanan dengan rating tertinggi.

# %%
print(df_all[df_all["Shop_name"] == 'Soto mi khas bogor "mbak Yul"'])

longitude_pattern = '(?<=,)(-?\d+\.\d+)(?=,)'
latitude_pattern = '(?<=@)(.+?)(?=,)'

df_all['Latitude'] = df_all['Page_URL'].apply(lambda x: re.findall(latitude_pattern, x)[0])
df_all['Longitude'] = df_all['Page_URL'].apply(lambda x: re.findall(longitude_pattern, x)[0])

print(df_all[df_all["Shop_name"] == 'Soto mi khas bogor "mbak Yul"'])
print(df_all[df_all["Shop_name"] == 'Soto mi khas bogor "mbak Yul"']["Page_URL"])
# Out:
#                                               Page_URL  \
# 186  https://www.google.com/maps/place/Soto+Sekarta...
#
#                          Shop_name  Rating  Reviews Kategori  \
# 186  Soto mi khas bogor "mbak Yul"     5.0        1     Soto
#
#                                                Address Phone_Number  \
# 186  Jl. Raya Solo No.39-51, Tegalharjo, Kec. Jebre...            0
#
#                                          Opening_Hours Range_Harga  \
# 186  {'Senin': ['12.00–21.00'], 'Selasa': ['12.00–2...  Rp 1–25 rb
#
#     Deskripsi_Toko   Latitude    Longitude  Eco_Friendly Categorize_Weather
# 186            NaN  -7.536801  110.6580492             0             Dingin
#                                               Page_URL  \
# 186  https://www.google.com/maps/place/Soto+Sekarta...
#
#                          Shop_name  Rating  Reviews Kategori  \
# 186  Soto mi khas bogor "mbak Yul"     5.0        1     Soto
#
#                                                Address Phone_Number  \
# 186  Jl. Raya Solo No.39-51, Tegalharjo, Kec. Jebre...            0
#
#                                          Opening_Hours Range_Harga  \
# 186  {'Senin': ['12.00–21.00'], 'Selasa': ['12.00–2...  Rp 1–25 rb
#
#     Deskripsi_Toko   Latitude    Longitude  Eco_Friendly Categorize_Weather
# 186            NaN  -7.536801  110.6580492             0             Dingin
# 186    https://www.google.com/maps/place/Soto+Sekarta...
# Name: Page_URL, dtype: object

# %%
# prompt: buatkan coding untuk mendownload df_all  dalam bentuk excel

from google.colab import files
df_all.to_excel(getcwd() + '/drive/Shareddrives/CAPSTONE_ML/df_all[duplicated].xlsx', index=False)
# files.download('df_all.xlsx')

# %%
df_new = pd.read_excel(getcwd() + '/drive/Shareddrives/CAPSTONE_ML/df_all[duplicated].xlsx')
df_new['Page_URL'].duplicated().sum()
# Out:
# 0

# %%
longitude_pattern = '(?<=,)(-?\d+\.\d+)(?=,)'
latitude_pattern = '(?<=@)(.+?)(?=,)'

df_new['Latitude'] = df_new['Page_URL'].apply(lambda x: re.findall(latitude_pattern, x)[0])
df_new['Longitude'] = df_new['Page_URL'].apply(lambda x: re.findall(longitude_pattern, x)[0])

df_new.drop(['Deskripsi_Toko'], axis=1, inplace=True)

df_new.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Uwuh+...
# 1  https://www.google.com/maps/place/Rajanya+JAHE...
# 2  https://www.google.com/maps/place/Wedang+uwuh+...
# 3  https://www.google.com/maps/place/Wedang+uwuh+...
# 4  https://www.google.com/maps/place/wedang+uwuh+...
#
#                                  Shop_name  Rating  Reviews     Kategori  \
# 0              Wedang Uwuh Solo - Pak Aden     4.6        5  Wedang Uwuh
# 1  Rajanya JAHE REMPAH wedhang uwuh Sumber     4.6       32  Wedang Uwuh
# 2                Wedang uwuh jelantik solo     5.0        1  Wedang Uwuh
# 3                     Wedang uwuh mbok tuo     4.9       14  Wedang Uwuh
# 4                          wedang uwuh sya     4.7        3  Wedang Uwuh
#
#                                              Address  Phone_Number  \
# 0  Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...  082324006000
# 1  Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...  085641727445
# 2  Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...  081229070267
# 3  Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...  081578614885
# 4  Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...  089608149211
#
#                                        Opening_Hours Range_Harga    Latitude  \
# 0  {'Senin': ['08.00–20.00'], 'Selasa': ['08.00–2...  Rp 1–25 rb  -7.5667314
# 1  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb  -7.5667314
# 2  {'Senin': ['Buka 24 jam'], 'Selasa': ['Buka 24...  Rp 1–25 rb   -7.576765
# 3  {'Senin': ['07.00–19.00'], 'Selasa': ['07.00–1...  Rp 1–25 rb  -7.5478945
# 4  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb  -7.5478945
#
#      Longitude  Eco_Friendly Categorize_Weather
# 0  110.7169194             0             Dingin
# 1  110.7169194             0             Dingin
# 2  110.7682294             0             Dingin
# 3  110.7308112             0             Dingin
# 4  110.7308112             0             Dingin

# %%
from google.colab import files
df_new.to_excel(getcwd() + '/drive/Shareddrives/CAPSTONE_ML/df_all_new.xlsx', index=False)
# files.download('df_all.xlsx')

# %%
df_new[df_new["Reviews"] > 1000]
# Out:
#                                               Page_URL  \
# 7    https://www.google.com/maps/place/Wedangan+Nal...
# 12   https://www.google.com/maps/place/Wedangan+Pen...
# 13   https://www.google.com/maps/place/Angkringan+O...
# 15   https://www.google.com/maps/place/Omah+Londo+A...
# 20   https://www.google.com/maps/place/Wedangan+Man...
# ..                                                 ...
# 487  https://www.google.com/maps/place/Tengkleng+So...
# 498  https://www.google.com/maps/place/Gudeg+Mbak+Y...
# 505  https://www.google.com/maps/place/Gudeg+Podhom...
# 517  https://www.google.com/maps/place/Rumah+Makan+...
# 518  https://www.google.com/maps/place/Adem+Ayem+Re...
#
#                            Shop_name  Rating  Reviews     Kategori  \
# 7               Wedangan Nala Gareng     4.5     1581  Wedang Uwuh
# 12                 Wedangan Pendhopo     4.5     2043  Wedang Uwuh
# 13           Angkringan Omahe Whawin     4.4     2170  Wedang Uwuh
# 15             Omah Londo Angkringan     4.3     2597  Wedang Uwuh
# 20                   Wedangan Mantap     4.5     2572  Wedang Uwuh
# ..                               ...     ...      ...          ...
# 487  Tengkleng Solo Bu Jito "Dlidir"     4.3     1293  Sate Buntel
# 498                   Gudeg Mbak Yus     4.4     1136        Gudeg
# 505           Gudeg Podhomoro Relasi     4.7     1373        Gudeg
# 517         Rumah Makan Gudeg Bu Dul     4.4     2037        Gudeg
# 518    Adem Ayem Resto Slamet Riyadi     4.5    11933        Gudeg
#
#                                                Address   Phone_Number  \
# 7    Jl. Basuki Rahmat No.6, RT.2/RW.12, Kerten, Ke...   081386055025
# 12   Jl. Srigading I No.20, Mangkubumen, Kec. Banja...              0
# 13   Jl. Kelud Selatan no.42, Jl. Nayu Utara Kelura...              0
# 15   Jl. Agus Salim No.2A, Sondakan, Kec. Laweyan, ...  (0271) 713741
# 20   Jl. Sugiyopranoto No.12, Kp. Baru, Kec. Ps. Kl...   081802592816
# ..                                                 ...            ...
# 487  Jl. Kolonel Sugiyono No.67, Kadipiro, Kec. Ban...   085725244787
# 498  Jl. RA Kartini No.12, Timuran, Kec. Banjarsari...   081280205859
# 505  Jl. Sidomulyo Gg. X No.14, Dusun II, Makamhaji...              0
# 517  Jl. Diponegoro No.88, Wirocanan, Kertonatan, K...   085741231102
# 518  Jl. Slamet Riyadi No.342, Penumping, Kec. Lawe...  (0271) 712891
#
#                                          Opening_Hours  Range_Harga  \
# 7    {'Senin': ['16.30–00.00'], 'Selasa': ['16.30–0...  Rp 25–50 rb
# 12   {'Senin': ['15.00–22.00'], 'Selasa': ['15.00–2...  Rp 25–50 rb
# 13   {'Senin': ['10.00–23.00'], 'Selasa': ['10.00–2...  Rp 25–50 rb
# 15   {'Senin': ['08.00–23.00'], 'Selasa': ['08.00–2...  Rp 25–50 rb
# 20   {'Senin': ['07.00–12.30', '16.00–22.30'], 'Sel...  Rp 25–50 rb
# ..                                                 ...          ...
# 487  {'Minggu': ['09.00–18.30'], 'Senin': ['09.00–1...  Rp 25–50 rb
# 498  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 25–50 rb
# 505  {'Minggu': ['12.00–22.30'], 'Senin': ['12.00–2...   Rp 1–25 rb
# 517  {'Minggu': ['08.00–21.00'], 'Senin': ['08.00–2...  Rp 25–50 rb
# 518  {'Minggu': ['06.00–21.00'], 'Senin': ['06.00–2...  Rp 50–75 rb
#
#        Latitude    Longitude  Eco_Friendly Categorize_Weather
# 7    -7.5478945  110.7308112             0             Dingin
# 12   -7.5621768  110.7405513             0             Dingin
# 13   -7.5621768  110.7405513             0             Dingin
# 15   -7.5621768  110.7405513             0             Dingin
# 20   -7.5677548  110.7554033             0             Dingin
# ..          ...          ...           ...                ...
# 487  -7.5457468  110.7909469             1       Dingin/Panas
# 498  -7.5579776  110.6736424             1       Dingin/Panas
# 505  -7.5579776  110.6736424             1       Dingin/Panas
# 517  -7.5527569  110.5992039             1       Dingin/Panas
# 518  -7.5631516  110.6748293             1       Dingin/Panas
#
# [63 rows x 13 columns]
