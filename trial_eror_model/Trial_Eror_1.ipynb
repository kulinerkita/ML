# %% [markdown]
# # Import Library

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import re
from os import getcwd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cwd = getcwd() + "/drive/Shareddrives/CAPSTONE_ML/"
print(cwd)
# Out:
# /content/drive/Shareddrives/CAPSTONE_ML/

# %%
df_all = pd.read_excel(cwd + "df_all_new.xlsx")
df_all.head()
# Out:
#                                             Page_URL  \
# 0  https://www.google.com/maps/place/Wedang+Uwuh+...
# 1  https://www.google.com/maps/place/Rajanya+JAHE...
# 2  https://www.google.com/maps/place/Wedang+uwuh+...
# 3  https://www.google.com/maps/place/Wedang+uwuh+...
# 4  https://www.google.com/maps/place/wedang+uwuh+...
#
#                                  Shop_name  Rating  Reviews     Kategori  \
# 0              Wedang Uwuh Solo - Pak Aden     4.6        5  Wedang Uwuh
# 1  Rajanya JAHE REMPAH wedhang uwuh Sumber     4.6       32  Wedang Uwuh
# 2                Wedang uwuh jelantik solo     5.0        1  Wedang Uwuh
# 3                     Wedang uwuh mbok tuo     4.9       14  Wedang Uwuh
# 4                          wedang uwuh sya     4.7        3  Wedang Uwuh
#
#                                              Address  Phone_Number  \
# 0  Mutihan rt 04 rw 1, Surakarta, Sondakan, Kec. ...  082324006000
# 1  Jl. Letjen Suprapto No.76c, Sumber, Kec. Banja...  085641727445
# 2  Jl. Sungai Musi No.1, Sangkrah, Kec. Ps. Kliwo...  081229070267
# 3  Jl. Kutai Tim. 5B, RT.05/RW.08, Sumber, Kec. B...  081578614885
# 4  Jl. Reksoniten No.20, Gajahan, Kec. Ps. Kliwon...  089608149211
#
#                                        Opening_Hours Range_Harga  Latitude  \
# 0  {'Senin': ['08.00–20.00'], 'Selasa': ['08.00–2...  Rp 1–25 rb -7.566731
# 1  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb -7.566731
# 2  {'Senin': ['Buka 24 jam'], 'Selasa': ['Buka 24...  Rp 1–25 rb -7.576765
# 3  {'Senin': ['07.00–19.00'], 'Selasa': ['07.00–1...  Rp 1–25 rb -7.547894
# 4  {'Minggu': ['Buka 24 jam'], 'Senin': ['Buka 24...  Rp 1–25 rb -7.547894
#
#     Longitude  Eco_Friendly Categorize_Weather
# 0  110.716919             0             Dingin
# 1  110.716919             0             Dingin
# 2  110.768229             0             Dingin
# 3  110.730811             0             Dingin
# 4  110.730811             0             Dingin

# %% [markdown]
# Fungsi untuk menghitung jarak menggunakan formula haversine

# %%
def calculate_haversine(lat1, lon1, lat2, lon2):
    earth_radius = 6371  # Radius bumi dalam kilometer
    delta_lat = np.radians(lat2 - lat1)
    delta_lon = np.radians(lon2 - lon1)
    a = np.sin(delta_lat / 2)**2 + np.cos(np.radians(lat1)) * np.cos(np.radians(lat2)) * np.sin(delta_lon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return earth_radius * c

# %% [markdown]
# Menghitung jarak tiap lokasi berdasarkan input latitude dan longitude pengguna

# %%
# Lokasi pengguna
current_lat = -7.5589608
current_lon = 110.856106

# Perhitungan jarak untuk setiap lokasi dalam dataset
df_all['computed_distance'] = df_all.apply(
    lambda row: calculate_haversine(current_lat, current_lon, row['Latitude'], row['Longitude']), axis=1
)

# %%
df_all['Categorize_Weather'].value_counts()

C = df_all['Rating'].mean()
M = df_all['Reviews'].quantile(0.5)
df_all['weighted_rating'] = ((df_all['Reviews'] / (df_all['Reviews'] + M)) * df_all['Rating']) + ((M / (df_all['Reviews'] + M)) * C)

# %%
df_all.dtypes
# Out:
# Page_URL               object
# Shop_name              object
# Rating                float64
# Reviews                 int64
# Kategori               object
# Address                object
# Phone_Number           object
# Opening_Hours          object
# Range_Harga            object
# Latitude              float64
# Longitude             float64
# Eco_Friendly            int64
# Categorize_Weather     object
# computed_distance     float64
# weighted_rating       float64
# dtype: object

# %%
selected_df = df_all[['Categorize_Weather', 'weighted_rating', 'Kategori', 'Rating']]

# train, test = train_test_split(selected_df, test_size=0.2, random_state=42)
train, val = train_test_split(selected_df, test_size=0.2, random_state=42)

print(len(train), 'train examples')
print(len(val), 'validation examples')
# print(len(test), 'test examples')
# Out:
# 485 train examples
# 122 validation examples

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    dataframe = dataframe.copy()

    labels = dataframe.pop('Rating')

    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))

    if shuffle:
      ds = ds.shuffle(4)

    ds = ds.batch(batch_size)

    return ds

# %%
import tensorflow as tf
from tensorflow.keras.layers import Normalization, StringLookup, CategoryEncoding

# Data numerik
numeric_data = df_all['weighted_rating'].to_numpy()
normalizer = Normalization()
normalizer.adapt(numeric_data)

# Data kategorik: 'weather'
weather_class = ['Dingin', 'Dingin/Panas', 'Panas']
weather_lookup = StringLookup(vocabulary=weather_class, output_mode="one_hot")

# Data kategorik: 'category'
category_class = df_all['Kategori'].unique().tolist()
category_lookup = StringLookup(vocabulary=category_class, output_mode="one_hot")

# Contoh pipeline preprocessing
inputs = {
    "weighted_rating": tf.keras.Input(shape=(1,), name="weighted_rating"),
    "weather": tf.keras.Input(shape=(1,), name="weather", dtype=tf.string),
    "category": tf.keras.Input(shape=(1,), name="category", dtype=tf.string),
}

preprocessed = [
    normalizer(inputs["weighted_rating"]),
    weather_lookup(inputs["weather"]),
    category_lookup(inputs["category"]),
]

# Gabungkan semua preprocessing
concatenated = tf.keras.layers.Concatenate()(preprocessed)

# Model akhir
outputs = tf.keras.layers.Dense(10, activation="relu")(concatenated)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ weighted_rating           │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ weather (InputLayer)      │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ category (InputLayer)     │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 1)              │          1,215 │ weighted_rating[0][0]  │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ string_lookup             │ (None, 4)              │              0 │ weather[0][0]          │
# │ (StringLookup)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ string_lookup_1           │ (None, 18)             │              0 │ category[0][0]         │
# │ (StringLookup)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 23)             │              0 │ normalization[0][0],   │
# │                           │                        │                │ string_lookup[0][0],   │
# │                           │                        │                │ string_lookup_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 10)             │            240 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,455 (5.69 KB)
#  Trainable params: 240 (960.00 B)
#  Non-trainable params: 1,215 (4.75 KB)

# %%
feature_layer = tf.keras.layers.Concatenate()(preprocessed)

# %%
train_ds = df_to_dataset(train)
val_ds = df_to_dataset(val, shuffle=False)
# test_ds = df_to_dataset(test, shuffle=False)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(feature_layer.shape[1],)),
    feature_layer,
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mape'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-dc3b7535bd62> in <cell line: 1>()
# ----> 1 model = tf.keras.Sequential([
#       2     tf.keras.layers.InputLayer(input_shape=(feature_layer.shape[1],)),
#       3     feature_layer,
#       4     tf.keras.layers.Dense(128, activation='relu'),
#       5     tf.keras.layers.Dense(1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      72         if layers:
#      73             for layer in layers:
# ---> 74                 self.add(layer, rebuild=False)
#      75             self._maybe_rebuild()
#      76
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#      94                 layer = origin_layer
#      95         if not isinstance(layer, Layer):
# ---> 96             raise ValueError(
#      97                 "Only instances of `keras.Layer` can be "
#      98                 f"added to a Sequential model. Received: {layer} "
#
# ValueError: Only instances of `keras.Layer` can be added to a Sequential model. Received: <KerasTensor shape=(None, 23), dtype=float32, sparse=False, name=keras_tensor_5> (of type <class 'keras.src.backend.common.keras_tensor.KerasTensor'>)

# %%
model.fit(train_ds,
          validation_data=val_ds,
          epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4f10a013c5a9> in <cell line: 1>()
# ----> 1 model.fit(train_ds,
#       2           validation_data=val_ds,
#       3           epochs=100)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/trainer.py in _assert_compile_called(self, method_name)
#     999             else:
#    1000                 msg += f"calling `{method_name}()`."
# -> 1001             raise ValueError(msg)
#    1002
#    1003     def _symbolic_build(self, iterator=None, data_batch=None):
#
# ValueError: You must call `compile()` before using the model.

# %% [markdown]
# # Menggunakan input np hstack

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df_all['Kategori_encoded'] = label_encoder.fit_transform(df_all['Kategori'])
category = tf.keras.utils.to_categorical(df_all['Kategori_encoded'])

df_all['Categorize_Weather_encoded'] = label_encoder.fit_transform(df_all['Categorize_Weather'])
weather = tf.keras.utils.to_categorical(df_all['Categorize_Weather_encoded'])

# %%
C = df_all['Rating'].mean()
M = df_all['Reviews'].quantile(0.5)
df_all['weighted_rating'] = ((df_all['Reviews'] / (df_all['Reviews'] + M)) * df_all['Rating']) + ((M / (df_all['Reviews'] + M)) * C)

# df_all['weighted_rating'] = (df_all['Rating'] * np.log(df_all['Reviews'] + 1))

# %%
feature_input = np.hstack([category, weather, np.expand_dims(df_all['weighted_rating'].values, axis=1)])

# %%
feature_tensor = tf.convert_to_tensor(feature_input, dtype=tf.float32)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(feature_tensor.shape[1],)),
    # tf.keras.layers.Dense(512, activation='relu'),
    # tf.keras.layers.Dense(512, activation='relu'),
    # tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

target = df_all['Rating'].values

model.fit(feature_tensor, target, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 17.7552 - mae: 4.0329 - val_loss: 13.5118 - val_mae: 3.5730
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0555 - mae: 3.3807 - val_loss: 8.7694 - val_mae: 2.9201
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1605 - mae: 2.6267 - val_loss: 5.3036 - val_mae: 2.2828
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8984 - mae: 1.9206 - val_loss: 3.1399 - val_mae: 1.7001
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1251 - mae: 1.3060 - val_loss: 2.1771 - val_mae: 1.2807
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5277 - mae: 0.8870 - val_loss: 1.8192 - val_mae: 1.0133
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3490 - mae: 0.6232 - val_loss: 1.7333 - val_mae: 0.9146
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1482 - mae: 0.5581 - val_loss: 1.7219 - val_mae: 0.8988
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4374 - mae: 0.6163 - val_loss: 1.7536 - val_mae: 0.9401
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0622 - mae: 0.5243 - val_loss: 1.7455 - val_mae: 0.9301
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4563 - mae: 0.6292 - val_loss: 1.7377 - val_mae: 0.9201
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1590 - mae: 0.5401 - val_loss: 1.7390 - val_mae: 0.9217
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4580 - mae: 0.6218 - val_loss: 1.7390 - val_mae: 0.9216
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4462 - mae: 0.6139 - val_loss: 1.7376 - val_mae: 0.9197
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4626 - mae: 0.6236 - val_loss: 1.7322 - val_mae: 0.9126
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2963 - mae: 0.5713 - val_loss: 1.7325 - val_mae: 0.9130
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3943 - mae: 0.5927 - val_loss: 1.7371 - val_mae: 0.9189
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1386 - mae: 0.5337 - val_loss: 1.7224 - val_mae: 0.8988
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0759 - mae: 0.5096 - val_loss: 1.7310 - val_mae: 0.9109
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9799 - mae: 0.5141 - val_loss: 1.7350 - val_mae: 0.9161
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2776 - mae: 0.5953 - val_loss: 1.7673 - val_mae: 0.9570
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5004 - mae: 0.6538 - val_loss: 1.7475 - val_mae: 0.9325
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1384 - mae: 0.5613 - val_loss: 1.7348 - val_mae: 0.9161
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3504 - mae: 0.5962 - val_loss: 1.7308 - val_mae: 0.9108
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2303 - mae: 0.5709 - val_loss: 1.7574 - val_mae: 0.9454
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3303 - mae: 0.6010 - val_loss: 1.7350 - val_mae: 0.9168
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1883 - mae: 0.5472 - val_loss: 1.7334 - val_mae: 0.9147
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0926 - mae: 0.5330 - val_loss: 1.7468 - val_mae: 0.9318
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2499 - mae: 0.5711 - val_loss: 1.7335 - val_mae: 0.9146
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4868 - mae: 0.6280 - val_loss: 1.7425 - val_mae: 0.9263
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9755 - mae: 0.5105 - val_loss: 1.7240 - val_mae: 0.9015
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2471 - mae: 0.5598 - val_loss: 1.7248 - val_mae: 0.9026
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1412 - mae: 0.5550 - val_loss: 1.7309 - val_mae: 0.9109
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2103 - mae: 0.5680 - val_loss: 1.7322 - val_mae: 0.9126
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3229 - mae: 0.5848 - val_loss: 1.7274 - val_mae: 0.9062
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3047 - mae: 0.5761 - val_loss: 1.7332 - val_mae: 0.9144
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4607 - mae: 0.6333 - val_loss: 1.7497 - val_mae: 0.9366
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3718 - mae: 0.6009 - val_loss: 1.7166 - val_mae: 0.8913
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5174 - mae: 0.6369 - val_loss: 1.7202 - val_mae: 0.8967
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1660 - mae: 0.5500 - val_loss: 1.7248 - val_mae: 0.9031
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1399 - mae: 0.5508 - val_loss: 1.7409 - val_mae: 0.9249
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2366 - mae: 0.5930 - val_loss: 1.7266 - val_mae: 0.9056
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2528 - mae: 0.5758 - val_loss: 1.7373 - val_mae: 0.9199
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3551 - mae: 0.6121 - val_loss: 1.7172 - val_mae: 0.8917
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4625 - mae: 0.6316 - val_loss: 1.7348 - val_mae: 0.9167
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1998 - mae: 0.5601 - val_loss: 1.7195 - val_mae: 0.8958
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1219 - mae: 0.5573 - val_loss: 1.7409 - val_mae: 0.9260
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5056 - mae: 0.6585 - val_loss: 1.7540 - val_mae: 0.9430
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2958 - mae: 0.6055 - val_loss: 1.7110 - val_mae: 0.8831
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2604 - mae: 0.5691 - val_loss: 1.7100 - val_mae: 0.8816
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0380 - mae: 0.5231 - val_loss: 1.7331 - val_mae: 0.9156
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1471 - mae: 0.5773 - val_loss: 1.7454 - val_mae: 0.9325
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1431 - mae: 0.5528 - val_loss: 1.7277 - val_mae: 0.9083
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3131 - mae: 0.5977 - val_loss: 1.7392 - val_mae: 0.9243
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5994 - mae: 0.6777 - val_loss: 1.7365 - val_mae: 0.9202
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2333 - mae: 0.5849 - val_loss: 1.7053 - val_mae: 0.8745
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2472 - mae: 0.5655 - val_loss: 1.7264 - val_mae: 0.9065
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1752 - mae: 0.5778 - val_loss: 1.7563 - val_mae: 0.9464
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3714 - mae: 0.6300 - val_loss: 1.7351 - val_mae: 0.9183
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1980 - mae: 0.5612 - val_loss: 1.7083 - val_mae: 0.8797
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2368 - mae: 0.5655 - val_loss: 1.7317 - val_mae: 0.9138
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2086 - mae: 0.5526 - val_loss: 1.7141 - val_mae: 0.8890
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0901 - mae: 0.5164 - val_loss: 1.7035 - val_mae: 0.8720
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2355 - mae: 0.5724 - val_loss: 1.7342 - val_mae: 0.9183
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1408 - mae: 0.5534 - val_loss: 1.7015 - val_mae: 0.8690
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2035 - mae: 0.5654 - val_loss: 1.7152 - val_mae: 0.8910
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3794 - mae: 0.6070 - val_loss: 1.7106 - val_mae: 0.8830
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9669 - mae: 0.5002 - val_loss: 1.7070 - val_mae: 0.8771
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2819 - mae: 0.5713 - val_loss: 1.7203 - val_mae: 0.8982
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1442 - mae: 0.5624 - val_loss: 1.7168 - val_mae: 0.8926
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5024 - mae: 0.6437 - val_loss: 1.7072 - val_mae: 0.8777
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3362 - mae: 0.5760 - val_loss: 1.7083 - val_mae: 0.8795
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5349 - mae: 0.6629 - val_loss: 1.7240 - val_mae: 0.9036
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2712 - mae: 0.5756 - val_loss: 1.7145 - val_mae: 0.8897
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1795 - mae: 0.5526 - val_loss: 1.7082 - val_mae: 0.8808
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1742 - mae: 0.5483 - val_loss: 1.7099 - val_mae: 0.8836
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1150 - mae: 0.5410 - val_loss: 1.7014 - val_mae: 0.8694
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2594 - mae: 0.5750 - val_loss: 1.6970 - val_mae: 0.8612
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2034 - mae: 0.5547 - val_loss: 1.6976 - val_mae: 0.8620
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1567 - mae: 0.5519 - val_loss: 1.7111 - val_mae: 0.8845
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2600 - mae: 0.5799 - val_loss: 1.7059 - val_mae: 0.8761
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3809 - mae: 0.6167 - val_loss: 1.6950 - val_mae: 0.8570
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2646 - mae: 0.5729 - val_loss: 1.7215 - val_mae: 0.9010
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2472 - mae: 0.5858 - val_loss: 1.6877 - val_mae: 0.8433
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9626 - mae: 0.4975 - val_loss: 1.7079 - val_mae: 0.8796
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2984 - mae: 0.6132 - val_loss: 1.6977 - val_mae: 0.8621
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4727 - mae: 0.6401 - val_loss: 1.7089 - val_mae: 0.8812
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2194 - mae: 0.5713 - val_loss: 1.6996 - val_mae: 0.8657
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3628 - mae: 0.6080 - val_loss: 1.6953 - val_mae: 0.8585
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3026 - mae: 0.5624 - val_loss: 1.7005 - val_mae: 0.8681
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1947 - mae: 0.5658 - val_loss: 1.6925 - val_mae: 0.8539
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1823 - mae: 0.5483 - val_loss: 1.6935 - val_mae: 0.8553
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1322 - mae: 0.5335 - val_loss: 1.6966 - val_mae: 0.8603
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1219 - mae: 0.5269 - val_loss: 1.6962 - val_mae: 0.8598
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9734 - mae: 0.4967 - val_loss: 1.6872 - val_mae: 0.8433
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2219 - mae: 0.5938 - val_loss: 1.7145 - val_mae: 0.8917
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2190 - mae: 0.5682 - val_loss: 1.6805 - val_mae: 0.8280
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2246 - mae: 0.5707 - val_loss: 1.6861 - val_mae: 0.8404
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0702 - mae: 0.5202 - val_loss: 1.6974 - val_mae: 0.8628
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1733 - mae: 0.5589 - val_loss: 1.6885 - val_mae: 0.8456

# %%
test_loss, test_mae = model.evaluate(feature_tensor, target, verbose=0)
print(f"Mean Absolute Error pada data uji: {test_mae}")
# Out:
# Mean Absolute Error pada data uji: 0.6267900466918945

# %%
# Langkah 2: Prediksi menggunakan model yang sudah dilatih
predictions = model.predict(feature_tensor)  # Hasil prediksi berupa array

# Langkah 3: Tambahkan prediksi ke df_all sebagai kolom baru
df_all['toprecommendation'] = predictions
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
top_recommendations = df_all.sort_values(by='toprecommendation', ascending=False).head(607)
print(top_recommendations[['Shop_name', 'Kategori', 'Categorize_Weather', 'weighted_rating', 'Rating', 'Reviews', 'toprecommendation']])
# Out:
#                                   Shop_name          Kategori  \
# 121                     Soto Solo Mas Bedjo              Soto
# 266            Warung Selat & Sop "LEZATIE"             Selat
# 378                   Nasi Liwet Mbak Yanti        Sego Liwet
# 369                  Nasi liwet mbak endang        Sego Liwet
# 485                          Sate Pak Pledi       Sate Buntel
# ..                                      ...               ...
# 292              Aneka Sop Dan Selat J Nice             Selat
# 576           Es Gempol Pleret Abang Muscle  Es Gempol Pleret
# 35                    Angkringan Omah Semar       Wedang Uwuh
# 573   Es Gempol Pleret & Es Dawet Mbak Lena  Es Gempol Pleret
# 373  Nasi Liwet dan Ayam Geprek Mbak Laksmi        Sego Liwet
#
#     Categorize_Weather  weighted_rating  Rating  Reviews  toprecommendation
# 121             Dingin         4.768433     4.9       85           4.756782
# 266             Dingin         4.915769     5.0      173           4.749982
# 378             Dingin         4.655013     4.9       35           4.748380
# 369             Dingin         4.641650     4.9       32           4.736915
# 485       Dingin/Panas         4.753661     4.8      234           4.731956
# ..                 ...              ...     ...      ...                ...
# 292             Dingin         3.674744     2.6       13           3.754145
# 576              Panas         4.282208     0.0        0           3.727247
# 35              Dingin         3.710175     3.7     1293           3.623782
# 573              Panas         4.054224     3.9       34           3.546439
# 373             Dingin         2.430741     1.1       32           2.800341
#
# [607 rows x 7 columns]

# %%
top_nasi_liwet = top_recommendations[top_recommendations['Kategori'] == 'Sego Liwet'].sort_values(by='toprecommendation', ascending=False).head(10)
print(top_nasi_liwet[['Shop_name', 'Kategori', 'Categorize_Weather', 'weighted_rating', 'Rating', 'Reviews', 'toprecommendation']])

# top_recommendations[top_recommendations['Kategori'] == 'Sego Liwet']
# Out:
#                               Shop_name    Kategori Categorize_Weather  \
# 378               Nasi Liwet Mbak Yanti  Sego Liwet             Dingin
# 369              Nasi liwet mbak endang  Sego Liwet             Dingin
# 363               Nasi Liwet Mbah Kisut  Sego Liwet             Dingin
# 345                   Nasi Liwet Sukini  Sego Liwet             Dingin
# 310  Nasi Liwet & Cabuk Rambak Bu Parmi  Sego Liwet             Dingin
# 341  Nasi Liwet & Bubur Lemu Mbah Narti  Sego Liwet             Dingin
# 326        Nasi Liwet Mbak Marni Gentan  Sego Liwet             Dingin
# 331     Nasi Liwet MBAK GIYEM Solo Baru  Sego Liwet             Dingin
# 325                 Nasi Liwet Bu Darmi  Sego Liwet             Dingin
# 346      nasi liwet solo pagi mbak atin  Sego Liwet             Dingin
#
#      weighted_rating  Rating  Reviews  toprecommendation
# 378         4.655013     4.9       35           4.748380
# 369         4.641650     4.9       32           4.736915
# 363         4.626746     4.9       29           4.724126
# 345         4.621876     4.7      100           4.719949
# 310         4.594768     4.6     1374           4.696691
# 341         4.591162     4.6      804           4.693597
# 326         4.575298     4.8       30           4.679986
# 331         4.571224     4.6      231           4.676490
# 325         4.570166     4.6      222           4.675583
# 346         4.570146     4.7       51           4.675565
